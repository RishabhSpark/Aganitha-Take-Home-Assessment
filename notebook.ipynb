# %%
import requests
import xml.etree.ElementTree as ET
import re
from typing import List, Dict, Any, Optional
import logging

# %%
# Setting up logging
logging.basicConfig(level=logging.DEBUG, format='%(asctime)s - %(levelname)s - %(message)s')

# %%
# Function to fetch PubMed IDs based on a search query
def fetch_paper_ids_from_pubmed(query: str, max_results: int = 10) -> List[str]:
    base_url = "https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi"
    params = {
        'db': 'pubmed',
        'term': query,
        'retmax': max_results,  # Limit the number of results
        'usehistory': 'y',      # Use history for retrieving large result sets
        'retmode': 'xml'
    }

    # Log the query and parameters
    logging.debug(f"Fetching PubMed IDs for query: {query} with parameters: {params}")

    try:
        # Send the request to fetch paper IDs
        response = requests.get(base_url, params=params)

        # Check if the response status is successful
        if response.status_code == 200:
            logging.info(f"Successfully fetched paper IDs for query: {query}")
            
            # Parse the XML response to extract paper IDs
            root = ET.fromstring(response.content)
            
            # Extract the list of paper IDs from the XML response
            id_list = [id_tag.text for id_tag in root.findall(".//Id")]

            logging.debug(f"Fetched {len(id_list)} paper IDs")
            return id_list
        else:
            logging.error(f"Error fetching paper IDs: {response.status_code}")
            return []
    except requests.exceptions.RequestException as e:
        # Log the error if the request fails
        logging.error(f"Request failed: {e}")
        return []

# %%
# Function to send the request and get the paper's XML data
def fetch_xml_data(pubmed_id: str) -> Optional[ET.Element]:
    base_url = "https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi"
    params = {
        'db': 'pubmed',
        'id': pubmed_id,
        'retmode': 'xml'
    }

    # Log the request details
    logging.debug(f"Fetching XML data for PubMed ID: {pubmed_id} with parameters: {params}")

    try:
        # Send the request to fetch detailed paper information
        response = requests.get(base_url, params=params)
        response.raise_for_status()  # Raise an exception for HTTP errors
        
        # Check if the response status is successful
        if response.status_code == 200:
            logging.info(f"Successfully fetched XML data for PubMed ID: {pubmed_id}")
            return ET.fromstring(response.content)  # Return the XML root element
        else:
            logging.error(f"Error fetching paper details for PubMed ID {pubmed_id}: {response.status_code}")
            return None
    except requests.exceptions.RequestException as e:
        # Log the error if the request fails
        logging.error(f"Request failed for PubMed ID {pubmed_id}: {e}")
        return None

# %%
# # List of academic keywords to exclude
# academic_keywords = [
#     "University", "College", "Institute", "Academy", "School", 
#     "Faculty", "Academician", "PhD", "Professor"
# ]

# # Function to check if an affiliation is academic
# def is_academic(affiliation: str, academic_keywords = List[str]) -> bool:
#     logging.debug(f"Checking affiliation: {affiliation}")
#     for keyword in academic_keywords:
#         if keyword.lower() in affiliation.lower():
#             return True
        
#     logging.info(f"Affiliation '{affiliation}' is not academic.")
#     return False

import ollama
import logging

# Function to check if an affiliation is academic using Ollama, keeping the format the same
# Function to check if an affiliation is academic using Ollama
def is_academic_using_ollama(affiliation: str, model: str = "llama3:8b") -> bool:
    logging.debug(f"Checking affiliation: {affiliation}")

    # Prepare the prompt for Ollama, asking it to classify whether the affiliation is academic
    prompt = f"Is the following affiliation academic? {affiliation}. If academic, answer 'Yes'. Otherwise, answer 'No'."

    try:
        # Chat with Ollama to classify if affiliation is academic
        response = ollama.chat(model=model, messages=[{'role': 'user', 'content': prompt}])
        
        # Get the response content and process it
        result = response['message']['content'].strip().lower()
        
        # Check if Ollama's response indicates 'Yes' (academic) or 'No' (not academic)
        if 'yes' in result:
            logging.info(f"Affiliation '{affiliation}' is academic.")
            return True
        elif 'no' in result:
            logging.info(f"Affiliation '{affiliation}' is not academic.")
            return False
        else:
            logging.info(f"Unclear response from Ollama for '{affiliation}'")
            return False
    except Exception as e:
        logging.error(f"Error occurred while checking affiliation: {e}")
        return False
# Out:
# 2025-04-12 22:39:24,887 - DEBUG - load_ssl_context verify=True cert=None trust_env=True http2=False
# 2025-04-12 22:39:24,895 - DEBUG - load_verify_locations cafile='c:\\Users\\khand\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\site-packages\\certifi\\cacert.pem'

# %%
# List of pharmaceutical and biotech-related keywords to identify relevant companies
pharma_biotech_keywords = [
    "Pharmaceutical", "Biotech", "Biotechnology", "Pharma", "Biopharma", 
    "Med", "Healthcare", "Bio", "Genetics", "Drug", "Therapeutics", "Vaccine",
    "Diagnostics", "Clinical", "Development", "Manufacturing"
]

# Function to check if an affiliation is related to pharmaceutical or biotech companies
def is_pharma_biotech(affiliation: str, pharma_biotech_keywords = List[str]) -> bool:
    logging.debug(f"Checking affiliation: {affiliation}")

    for keyword in pharma_biotech_keywords:
        if keyword.lower() in affiliation.lower():
            return True
        
    logging.info(f"Affiliation is not related to pharma/biotech: {affiliation}")
    return False

# %%
# Function to extract PubMed ID
def get_pubmed_id(root: ET.Element, pubmed_id: str) -> str:
    logging.debug(f"Extracting PubMed ID: {pubmed_id}")
    return pubmed_id


# Function to extract the title of the paper
def get_title(root: ET.Element) -> str:
    title_tag = root.find(".//ArticleTitle")
    if title_tag is not None:
        logging.info(f"Title extracted: {title_tag.text}")
        return title_tag.text
    else:
        logging.warning("Title not found in the XML.")
        return "N/A"


# Function to extract the publication date
# def get_publication_date(root: ET.Element) -> str:
#     pub_date_tag = root.find(".//PubDate")
#     if pub_date_tag is not None:
#         year = pub_date_tag.find("Year")
#         month = pub_date_tag.find("Month")
#         day = pub_date_tag.find("Day")
#         if year is not None and month is not None and day is not None:
#             date = f"{year.text}-{month.text}-{day.text}"
#             logging.info(f"Publication date extracted: {date}")
#             return date
#         else:
#             logging.warning("Incomplete publication date found (missing year, month, or day).")
#             return "N/A"
#     else:
#         logging.warning("Publication date not found in the XML.")
#         return "N/A"


def get_publication_date(root: ET.Element) -> str:
    """Extracts the publication date from PubMed XML data and handles various date formats.

    Args:
        root (ET.Element): The XML root element containing the paper's metadata.

    Returns:
        str: The publication date in a consistent format ("YYYY-MM-DD"), or "N/A" if not found.
    """
    # Function to normalize the date format (if needed)
    def normalize_date(date: str) -> str:
        # Match different date formats and handle accordingly
        # Format: Year (e.g., "2020"), Year-Month (e.g., "2020 Aug"), Year-Month-Day (e.g., "2020 May 31")
        month_map = {
            "Jan": "01", "Feb": "02", "Mar": "03", "Apr": "04", "May": "05", "Jun": "06", 
            "Jul": "07", "Aug": "08", "Sep": "09", "Oct": "10", "Nov": "11", "Dec": "12"
        }
        
        # If the date has a month abbreviation (e.g., "2020 Aug"), replace it with month number
        match = re.match(r"(\d{4})\s*(\w{3})\s*(\d{1,2})?$", date)
        if match:
            year = match.group(1)
            month_str = match.group(2)
            day = match.group(3) if match.group(3) else "01"  # Default to 01 if day is missing
            month = month_map.get(month_str.capitalize(), "01")  # Default to January if month not found
            return f"{year}-{month}-{day}"

        # If the date is year-month (e.g., "2020 Aug"), default the day to 01
        match = re.match(r"(\d{4})\s*(\w{3})$", date)
        if match:
            year = match.group(1)
            month_str = match.group(2)
            month = month_map.get(month_str.capitalize(), "01")
            return f"{year}-{month}-01"

        # If only year (e.g., "2020"), return as "YYYY-01-01"
        match = re.match(r"(\d{4})$", date)
        if match:
            return f"{match.group(1)}-01-01"

        return date  # Return as is if no match

    # First, check for EPubDate (complete date)
    epub_date_tag = root.find(".//Item[@Name='EPubDate']")
    if epub_date_tag is not None and epub_date_tag.text:
        logging.info(f"EPubDate found: {epub_date_tag.text}")
        return normalize_date(epub_date_tag.text)  # Normalize and return date

    # Next, check for PubDate (year and possibly month)
    pub_date_tag = root.find(".//Item[@Name='PubDate']")
    if pub_date_tag is not None and pub_date_tag.text:
        # Normalize and return the PubDate
        logging.info(f"PubDate found: {pub_date_tag.text}")
        return normalize_date(pub_date_tag.text)

    # If neither date is found, return "N/A"
    logging.warning("Publication date not found.")
    return "N/A"

# %%
import requests
import xml.etree.ElementTree as ET

def fetch_pubmed_data(pubmed_id: str) -> ET.Element:
    """Fetches PubMed article metadata by PubMed ID and returns the XML root."""
    url = f"https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esummary.fcgi?db=pubmed&id={pubmed_id}&retmode=xml"
    
    response = requests.get(url)
    if response.status_code == 200:
        print(f"Successfully fetched PubMed data for ID: {pubmed_id}")
        # Parse the XML response
        return ET.fromstring(response.text)
    else:
        print(f"Failed to fetch PubMed data for ID: {pubmed_id}")
        return None

# Example PubMed ID (replace with a valid PubMed ID)
pubmed_id = "31168464"  # Example PubMed ID (replace with any valid ID)
root = fetch_xml_data(pubmed_id)

if root:
    # Now test the get_publication_date function on the fetched XML
    publication_date = get_publication_date(root)
    print("Extracted Publication Date:", publication_date)
# Out:
# 2025-04-12 22:39:25,245 - DEBUG - Fetching XML data for PubMed ID: 31168464 with parameters: {'db': 'pubmed', 'id': '31168464', 'retmode': 'xml'}
# 2025-04-12 22:39:25,258 - DEBUG - Starting new HTTPS connection (1): eutils.ncbi.nlm.nih.gov:443
# 2025-04-12 22:39:26,041 - DEBUG - https://eutils.ncbi.nlm.nih.gov:443 "GET /entrez/eutils/efetch.fcgi?db=pubmed&id=31168464&retmode=xml HTTP/11" 200 None
# 2025-04-12 22:39:26,210 - INFO - Successfully fetched XML data for PubMed ID: 31168464
# C:\Users\khand\AppData\Local\Temp\ipykernel_25084\4277641428.py:21: DeprecationWarning: Testing an element's truth value will always return True in future versions.  Use specific 'len(elem)' or 'elem is not None' test instead.
#   if root:
# 2025-04-12 22:39:26,226 - WARNING - Publication date not found.
# Extracted Publication Date: N/A

# %%
# import requests

# # Replace with a valid PubMed ID (PMID)
# pmid = "31158464"  # Example PMID
# url = f"https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esummary.fcgi?db=pubmed&id={pmid}&retmode=xml"

# response = requests.get(url)

# # Check the status code to ensure it's a successful response
# if response.status_code == 200:
#     xml_content = response.text
#     print(xml_content)
# else:
#     print(f"Failed to retrieve data: {response.status_code}")

# %%
# Function to extract authors
def get_authors(root: ET.Element, model: str = "llama3:8b") -> List[str]:
    logging.debug("Extracting authors from the XML data.")
    authors_tag = root.findall(".//AuthorList/Author")
    authors = []
    for author in authors_tag:
        last_name = author.find("LastName")
        fore_name = author.find("ForeName")
        affiliation_info = author.findall(".//AffiliationInfo/Affiliation")
        
        # Log the author information for debugging
        logging.debug(f"Processing author: {fore_name.text if fore_name is not None else 'N/A'} {last_name.text if last_name is not None else 'N/A'}")

        # Get the affiliations and check if they are non-academic using Ollama
        if affiliation_info:
            for aff in affiliation_info:
                logging.debug(f"Checking affiliation: {aff.text if aff is not None else 'N/A'}")
                if aff is not None and not is_academic_using_ollama(aff.text, model):
                    if last_name is not None and fore_name is not None:
                        author_name = f"{fore_name.text} {last_name.text}"
                        logging.info(f"Adding author: {author_name}")
                        authors.append(author_name)
                    break
        else:
            # If no affiliation is found, consider it as non-academic (fallback case)
            if last_name is not None and fore_name is not None:
                author_name = f"{fore_name.text} {last_name.text}"
                logging.info(f"Adding author: {author_name}")
                authors.append(author_name)
    
    if authors:
        logging.debug(f"Authors extracted: {authors}")
    else:
        logging.debug("No authors found.")

    return authors if authors else ["N/A"]


# Function to extract company affiliations
# def get_company_affiliations(root):
#     affiliations = []
#     authors_tag = root.findall(".//AuthorList/Author")
    
#     # Regex pattern to match and remove email and address
#     email_pattern = r"[\w\.-]+@[\w\.-]+"
#     address_pattern = r"\d{5},? \w+,\s?[A-Za-z\s]+"

#     for author in authors_tag:
#         aff_info = author.findall(".//AffiliationInfo/Affiliation")
#         for aff in aff_info:
#             if aff is not None:
#                 affiliation = aff.text
                
#                 # Remove email and address from affiliation string
#                 affiliation = re.sub(email_pattern, '', affiliation)  # Remove emails
#                 affiliation = re.sub(address_pattern, '', affiliation)  # Remove address
                
#                 # If there's still a valid affiliation left, add it
#                 if affiliation.strip():
#                     affiliations.append(affiliation.strip())
    
#     return affiliations if affiliations else ["N/A"]

# Regex pattern to match and remove email addresses
email_pattern = r"[\w\.-]+@[\w\.-]+"


def get_pharma_biotech_affiliations(root: ET.Element, pharma_biotech_keywords: List[str], model: str = "llama3:8b") -> List[str]:
    logging.debug("Extracting pharma/biotech affiliations from the XML data.")
    pharma_biotech_affiliations = []
    authors_tag = root.findall(".//AuthorList/Author")
    
    for author in authors_tag:
        aff_info = author.findall(".//AffiliationInfo/Affiliation")
        for aff in aff_info:
            if aff is not None:
                logging.debug(f"Checking affiliation: {aff.text}")
                
                # Check if the affiliation matches pharma/biotech and is non-academic using Ollama
                if is_pharma_biotech(aff.text, pharma_biotech_keywords) and not is_academic_using_ollama(aff.text, model):
                    # Remove email from affiliation text
                    clean_affiliation = re.sub(email_pattern, '', aff.text).strip()
                    
                    if clean_affiliation:  # Ensure there's something left after removing emails
                        logging.info(f"Adding pharma/biotech affiliation: {clean_affiliation}")
                        pharma_biotech_affiliations.append(clean_affiliation)
    
    if pharma_biotech_affiliations:
        logging.debug(f"Pharma/Biotech affiliations extracted: {pharma_biotech_affiliations}")
    else:
        logging.debug("No pharma/biotech affiliations found.")

    return set(pharma_biotech_affiliations) if pharma_biotech_affiliations else ["N/A"]


# Function to extract corresponding author email
def get_corresponding_email(
    root: ET.Element,
    model: str = "llama3:8b"
) -> List[str]:
    """Extracts non-academic corresponding author emails from the XML, using Ollama for academic classification."""
    logging.debug("Extracting corresponding email from the XML data.")
    emails = []

    authors_tag = root.findall(".//AuthorList/Author")
    for author in authors_tag:
        aff_info = author.findall(".//AffiliationInfo/Affiliation")
        for aff in aff_info:
            if aff is not None:
                logging.debug(f"Checking affiliation: {aff.text}")
                
                # Check if the affiliation is non-academic using Ollama
                if not is_academic_using_ollama(aff.text, model):
                    parts = aff.text.split() if aff.text else []
                    
                    for part in parts:
                        if "@" in part:
                            email = part.strip().strip(";,.()[]")
                            if email not in emails:
                                logging.info(f"Adding email: {email}")
                                emails.append(email)
    
    return emails if emails else ["N/A"]

# %%
# Main function to orchestrate the extraction
def fetch_paper_details(pubmed_id: str) -> Dict[str, Any]:
    logging.debug(f"Starting to fetch paper details for PubMed ID: {pubmed_id}")

    # Get XML data from PubMed
    root = fetch_xml_data(pubmed_id)
    
    if root is None:
        logging.error(f"Failed to fetch XML data for PubMed ID: {pubmed_id}")
        return {}

    paper_details = {}
    
    try:
        # Extracting paper details
        paper_details['PubMedID'] = get_pubmed_id(root, pubmed_id)
        logging.debug(f"PubMed ID: {paper_details['PubMedID']} extracted.")
        
        paper_details['Title'] = get_title(root)
        logging.debug(f"Title: {paper_details['Title']} extracted.")
        
        paper_details['PublicationDate'] = get_publication_date(root)
        logging.debug(f"Publication Date: {paper_details['PublicationDate']} extracted.")
        
        paper_details['Authors'] = get_authors(root, "llama3:8b")
        logging.debug(f"Authors: {paper_details['Authors']} extracted.")
        
        paper_details['CompanyAffiliations'] = get_pharma_biotech_affiliations(root, pharma_biotech_keywords, "llama3:8b")
        logging.debug(f"Company Affiliations: {paper_details['CompanyAffiliations']} extracted.")
        
        paper_details['CorrespondingAuthorEmail'] = get_corresponding_email(root, "llama3:8b")
        logging.debug(f"Corresponding Author Email: {paper_details['CorrespondingAuthorEmail']} extracted.")
        
    except Exception as e:
        logging.error(f"Error occurred while fetching paper details for PubMed ID {pubmed_id}: {e}")
        return {}

    logging.info(f"Successfully fetched paper details for PubMed ID: {pubmed_id}")
    return paper_details

# %%
# Function to fetch all paper details based on a query

def fetch_all_papers(query: str, max_results: int = 10) -> List[Dict[str, Any]]:
    logging.debug(f"Starting to fetch papers for query: {query}")
    
    # Fetch the paper IDs
    paper_ids = fetch_paper_ids_from_pubmed(query, max_results)
    
    if not paper_ids:
        logging.warning(f"No paper IDs found for query: {query}")
        return []
    
    logging.debug(f"Fetched {len(paper_ids)} paper IDs for query: {query}")

    # Fetch the details for each paper using the paper IDs
    all_paper_details = []
    for pubmed_id in paper_ids:
        logging.debug(f"Fetching details for PubMed ID: {pubmed_id}")
        paper_details = fetch_paper_details(pubmed_id)
        
        if paper_details:
            all_paper_details.append(paper_details)
            logging.debug(f"Successfully fetched details for PubMed ID: {pubmed_id}")
        else:
            logging.error(f"Failed to fetch details for PubMed ID: {pubmed_id}")
    
    logging.info(f"Successfully fetched details for {len(all_paper_details)} papers out of {len(paper_ids)} paper IDs.")
    
    return all_paper_details

# %%
query = "31158464"
papers = fetch_all_papers(query, max_results=20)

papers
# Out:
# 2025-04-12 22:39:26,313 - DEBUG - Starting to fetch papers for query: 31158464
# 2025-04-12 22:39:26,313 - DEBUG - Fetching PubMed IDs for query: 31158464 with parameters: {'db': 'pubmed', 'term': '31158464', 'retmax': 20, 'usehistory': 'y', 'retmode': 'xml'}
# 2025-04-12 22:39:26,317 - DEBUG - Starting new HTTPS connection (1): eutils.ncbi.nlm.nih.gov:443
# 2025-04-12 22:39:27,156 - DEBUG - https://eutils.ncbi.nlm.nih.gov:443 "GET /entrez/eutils/esearch.fcgi?db=pubmed&term=31158464&retmax=20&usehistory=y&retmode=xml HTTP/11" 200 None
# 2025-04-12 22:39:27,156 - INFO - Successfully fetched paper IDs for query: 31158464
# 2025-04-12 22:39:27,156 - DEBUG - Fetched 1 paper IDs
# 2025-04-12 22:39:27,156 - DEBUG - Fetched 1 paper IDs for query: 31158464
# 2025-04-12 22:39:27,156 - DEBUG - Fetching details for PubMed ID: 31158464
# 2025-04-12 22:39:27,156 - DEBUG - Starting to fetch paper details for PubMed ID: 31158464
# 2025-04-12 22:39:27,156 - DEBUG - Fetching XML data for PubMed ID: 31158464 with parameters: {'db': 'pubmed', 'id': '31158464', 'retmode': 'xml'}
# 2025-04-12 22:39:27,156 - DEBUG - Starting new HTTPS connection (1): eutils.ncbi.nlm.nih.gov:443
# 2025-04-12 22:39:28,154 - DEBUG - https://eutils.ncbi.nlm.nih.gov:443 "GET /entrez/eutils/efetch.fcgi?db=pubmed&id=31158464&retmode=xml HTTP/11" 200 None
# 2025-04-12 22:39:28,154 - INFO - Successfully fetched XML data for PubMed ID: 31158464
# 2025-04-12 22:39:28,188 - DEBUG - Extracting PubMed ID: 31158464
# 2025-04-12 22:39:28,188 - DEBUG - PubMed ID: 31158464 extracted.
# 2025-04-12 22:39:28,188 - INFO - Title extracted: Thyroid autoimmune disorders and cancer.
# 2025-04-12 22:39:28,188 - DEBUG - Title: Thyroid autoimmune disorders and cancer. extracted.
# 2025-04-12 22:39:28,188 - WARNING - Publication date not found.
# 2025-04-12 22:39:28,188 - DEBUG - Publication Date: N/A extracted.
# 2025-04-12 22:39:28,188 - DEBUG - Extracting authors from the XML data.
# 2025-04-12 22:39:28,188 - DEBUG - Processing author: Silvia Martina Ferrari
# 2025-04-12 22:39:28,188 - DEBUG - Checking affiliation: Department of Clinical and Experimental Medicine, University of Pisa, Pisa, Italy. Electronic address: sm.ferrari@int.med.unipi.it.
# 2025-04-12 22:39:28,188 - DEBUG - Checking affiliation: Department of Clinical and Experimental Medicine, University of Pisa, Pisa, Italy. Electronic address: sm.ferrari@int.med.unipi.it.
# 2025-04-12 22:39:28,199 - DEBUG - connect_tcp.started host='127.0.0.1' port=11434 local_address=None timeout=None socket_options=None
# 2025-04-12 22:39:28,199 - DEBUG - connect_tcp.complete return_value=<httpcore._backends.sync.SyncStream object at 0x0000018E664F4B60>
# 2025-04-12 22:39:28,199 - DEBUG - send_request_headers.started request=<Request [b'POST']>
# 2025-04-12 22:39:28,199 - DEBUG - send_request_headers.complete
# 2025-04-12 22:39:28,199 - DEBUG - send_request_body.started request=<Request [b'POST']>
# 2025-04-12 22:39:28,199 - DEBUG - send_request_body.complete
# 2025-04-12 22:39:28,210 - DEBUG - receive_response_headers.started request=<Request [b'POST']>
# 2025-04-12 22:39:52,775 - DEBUG - receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Content-Type', b'application/json; charset=utf-8'), (b'Date', b'Sat, 12 Apr 2025 17:09:52 GMT'), (b'Content-Length', b'300')])
# 2025-04-12 22:39:52,807 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-04-12 22:39:52,823 - DEBUG - receive_response_body.started request=<Request [b'POST']>
# 2025-04-12 22:39:52,823 - DEBUG - receive_response_body.complete
# 2025-04-12 22:39:52,823 - DEBUG - response_closed.started
# 2025-04-12 22:39:52,823 - DEBUG - response_closed.complete
# 2025-04-12 22:39:52,823 - INFO - Affiliation 'Department of Clinical and Experimental Medicine, University of Pisa, Pisa, Italy. Electronic address: sm.ferrari@int.med.unipi.it.' is academic.
# 2025-04-12 22:39:52,839 - DEBUG - Processing author: Poupak Fallahi
# 2025-04-12 22:39:52,839 - DEBUG - Checking affiliation: Department of Translational Research of New Technologies in Medicine and Surgery, University of Pisa, Pisa, Italy. Electronic address: poupak.fallahi@unipi.it.
# 2025-04-12 22:39:52,839 - DEBUG - Checking affiliation: Department of Translational Research of New Technologies in Medicine and Surgery, University of Pisa, Pisa, Italy. Electronic address: poupak.fallahi@unipi.it.
# 2025-04-12 22:39:52,839 - DEBUG - send_request_headers.started request=<Request [b'POST']>
# 2025-04-12 22:39:52,839 - DEBUG - send_request_headers.complete
# 2025-04-12 22:39:52,852 - DEBUG - send_request_body.started request=<Request [b'POST']>
# 2025-04-12 22:39:52,854 - DEBUG - send_request_body.complete
# 2025-04-12 22:39:52,855 - DEBUG - receive_response_headers.started request=<Request [b'POST']>
# 2025-04-12 22:39:54,417 - DEBUG - receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Content-Type', b'application/json; charset=utf-8'), (b'Date', b'Sat, 12 Apr 2025 17:09:54 GMT'), (b'Content-Length', b'297')])
# 2025-04-12 22:39:54,418 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-04-12 22:39:54,419 - DEBUG - receive_response_body.started request=<Request [b'POST']>
# 2025-04-12 22:39:54,420 - DEBUG - receive_response_body.complete
# 2025-04-12 22:39:54,421 - DEBUG - response_closed.started
# 2025-04-12 22:39:54,422 - DEBUG - response_closed.complete
# 2025-04-12 22:39:54,423 - INFO - Affiliation 'Department of Translational Research of New Technologies in Medicine and Surgery, University of Pisa, Pisa, Italy. Electronic address: poupak.fallahi@unipi.it.' is academic.
# 2025-04-12 22:39:54,423 - DEBUG - Processing author: Giusy Elia
# 2025-04-12 22:39:54,424 - DEBUG - Checking affiliation: Department of Clinical and Experimental Medicine, University of Pisa, Pisa, Italy. Electronic address: e.giusy_87@hotmail.it.
# 2025-04-12 22:39:54,424 - DEBUG - Checking affiliation: Department of Clinical and Experimental Medicine, University of Pisa, Pisa, Italy. Electronic address: e.giusy_87@hotmail.it.
# 2025-04-12 22:39:54,428 - DEBUG - send_request_headers.started request=<Request [b'POST']>
# 2025-04-12 22:39:54,430 - DEBUG - send_request_headers.complete
# 2025-04-12 22:39:54,439 - DEBUG - send_request_body.started request=<Request [b'POST']>
# 2025-04-12 22:39:54,441 - DEBUG - send_request_body.complete
# 2025-04-12 22:39:54,441 - DEBUG - receive_response_headers.started request=<Request [b'POST']>
# 2025-04-12 22:39:55,640 - DEBUG - receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Content-Type', b'application/json; charset=utf-8'), (b'Date', b'Sat, 12 Apr 2025 17:09:55 GMT'), (b'Content-Length', b'294')])
# 2025-04-12 22:39:55,641 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-04-12 22:39:55,641 - DEBUG - receive_response_body.started request=<Request [b'POST']>
# 2025-04-12 22:39:55,641 - DEBUG - receive_response_body.complete
# 2025-04-12 22:39:55,641 - DEBUG - response_closed.started
# 2025-04-12 22:39:55,641 - DEBUG - response_closed.complete
# 2025-04-12 22:39:55,641 - INFO - Affiliation 'Department of Clinical and Experimental Medicine, University of Pisa, Pisa, Italy. Electronic address: e.giusy_87@hotmail.it.' is not academic.
# 2025-04-12 22:39:55,641 - INFO - Adding author: Giusy Elia
# 2025-04-12 22:39:55,641 - DEBUG - Processing author: Francesca Ragusa
# 2025-04-12 22:39:55,641 - DEBUG - Checking affiliation: Department of Clinical and Experimental Medicine, University of Pisa, Pisa, Italy. Electronic address: francescaragusa86@gmail.com.
# 2025-04-12 22:39:55,641 - DEBUG - Checking affiliation: Department of Clinical and Experimental Medicine, University of Pisa, Pisa, Italy. Electronic address: francescaragusa86@gmail.com.
# 2025-04-12 22:39:55,641 - DEBUG - send_request_headers.started request=<Request [b'POST']>
# 2025-04-12 22:39:55,650 - DEBUG - send_request_headers.complete
# 2025-04-12 22:39:55,650 - DEBUG - send_request_body.started request=<Request [b'POST']>
# 2025-04-12 22:39:55,653 - DEBUG - send_request_body.complete
# 2025-04-12 22:39:55,655 - DEBUG - receive_response_headers.started request=<Request [b'POST']>
# 2025-04-12 22:39:56,936 - DEBUG - receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Content-Type', b'application/json; charset=utf-8'), (b'Date', b'Sat, 12 Apr 2025 17:09:56 GMT'), (b'Content-Length', b'296')])
# 2025-04-12 22:39:56,936 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-04-12 22:39:56,936 - DEBUG - receive_response_body.started request=<Request [b'POST']>
# 2025-04-12 22:39:56,936 - DEBUG - receive_response_body.complete
# 2025-04-12 22:39:56,936 - DEBUG - response_closed.started
# 2025-04-12 22:39:56,941 - DEBUG - response_closed.complete
# 2025-04-12 22:39:56,941 - INFO - Affiliation 'Department of Clinical and Experimental Medicine, University of Pisa, Pisa, Italy. Electronic address: francescaragusa86@gmail.com.' is academic.
# 2025-04-12 22:39:56,941 - DEBUG - Processing author: Ilaria Ruffilli
# 2025-04-12 22:39:56,941 - DEBUG - Checking affiliation: Department of Clinical and Experimental Medicine, University of Pisa, Pisa, Italy. Electronic address: ilaria.ruffilli@gmail.com.
# 2025-04-12 22:39:56,941 - DEBUG - Checking affiliation: Department of Clinical and Experimental Medicine, University of Pisa, Pisa, Italy. Electronic address: ilaria.ruffilli@gmail.com.
# 2025-04-12 22:39:56,949 - DEBUG - send_request_headers.started request=<Request [b'POST']>
# 2025-04-12 22:39:56,954 - DEBUG - send_request_headers.complete
# 2025-04-12 22:39:56,954 - DEBUG - send_request_body.started request=<Request [b'POST']>
# 2025-04-12 22:39:56,957 - DEBUG - send_request_body.complete
# 2025-04-12 22:39:56,959 - DEBUG - receive_response_headers.started request=<Request [b'POST']>
# 2025-04-12 22:39:58,781 - DEBUG - receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Content-Type', b'application/json; charset=utf-8'), (b'Date', b'Sat, 12 Apr 2025 17:09:58 GMT'), (b'Content-Length', b'297')])
# 2025-04-12 22:39:58,781 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-04-12 22:39:58,781 - DEBUG - receive_response_body.started request=<Request [b'POST']>
# 2025-04-12 22:39:58,781 - DEBUG - receive_response_body.complete
# 2025-04-12 22:39:58,781 - DEBUG - response_closed.started
# 2025-04-12 22:39:58,781 - DEBUG - response_closed.complete
# 2025-04-12 22:39:58,781 - INFO - Affiliation 'Department of Clinical and Experimental Medicine, University of Pisa, Pisa, Italy. Electronic address: ilaria.ruffilli@gmail.com.' is academic.
# 2025-04-12 22:39:58,781 - DEBUG - Processing author: Sabrina Rosaria Paparo
# 2025-04-12 22:39:58,781 - DEBUG - Checking affiliation: Department of Clinical and Experimental Medicine, University of Pisa, Pisa, Italy. Electronic address: sabrinapaparo@gmail.com.
# 2025-04-12 22:39:58,787 - DEBUG - Checking affiliation: Department of Clinical and Experimental Medicine, University of Pisa, Pisa, Italy. Electronic address: sabrinapaparo@gmail.com.
# 2025-04-12 22:39:58,787 - DEBUG - send_request_headers.started request=<Request [b'POST']>
# 2025-04-12 22:39:58,792 - DEBUG - send_request_headers.complete
# 2025-04-12 22:39:58,793 - DEBUG - send_request_body.started request=<Request [b'POST']>
# 2025-04-12 22:39:58,796 - DEBUG - send_request_body.complete
# 2025-04-12 22:39:58,797 - DEBUG - receive_response_headers.started request=<Request [b'POST']>
# 2025-04-12 22:40:00,313 - DEBUG - receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Content-Type', b'application/json; charset=utf-8'), (b'Date', b'Sat, 12 Apr 2025 17:10:00 GMT'), (b'Content-Length', b'296')])
# 2025-04-12 22:40:00,315 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-04-12 22:40:00,316 - DEBUG - receive_response_body.started request=<Request [b'POST']>
# 2025-04-12 22:40:00,317 - DEBUG - receive_response_body.complete
# 2025-04-12 22:40:00,319 - DEBUG - response_closed.started
# 2025-04-12 22:40:00,320 - DEBUG - response_closed.complete
# 2025-04-12 22:40:00,322 - INFO - Affiliation 'Department of Clinical and Experimental Medicine, University of Pisa, Pisa, Italy. Electronic address: sabrinapaparo@gmail.com.' is academic.
# 2025-04-12 22:40:00,324 - DEBUG - Processing author: Alessandro Antonelli
# 2025-04-12 22:40:00,326 - DEBUG - Checking affiliation: Department of Clinical and Experimental Medicine, University of Pisa, Pisa, Italy. Electronic address: alessandro.antonelli@med.unipi.it.
# 2025-04-12 22:40:00,327 - DEBUG - Checking affiliation: Department of Clinical and Experimental Medicine, University of Pisa, Pisa, Italy. Electronic address: alessandro.antonelli@med.unipi.it.
# 2025-04-12 22:40:00,329 - DEBUG - send_request_headers.started request=<Request [b'POST']>
# 2025-04-12 22:40:00,335 - DEBUG - send_request_headers.complete
# 2025-04-12 22:40:00,335 - DEBUG - send_request_body.started request=<Request [b'POST']>
# 2025-04-12 22:40:00,338 - DEBUG - send_request_body.complete
# 2025-04-12 22:40:00,340 - DEBUG - receive_response_headers.started request=<Request [b'POST']>
# 2025-04-12 22:40:02,403 - DEBUG - receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Content-Type', b'application/json; charset=utf-8'), (b'Date', b'Sat, 12 Apr 2025 17:10:02 GMT'), (b'Content-Length', b'297')])
# 2025-04-12 22:40:02,404 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-04-12 22:40:02,404 - DEBUG - receive_response_body.started request=<Request [b'POST']>
# 2025-04-12 22:40:02,404 - DEBUG - receive_response_body.complete
# 2025-04-12 22:40:02,404 - DEBUG - response_closed.started
# 2025-04-12 22:40:02,409 - DEBUG - response_closed.complete
# 2025-04-12 22:40:02,409 - INFO - Affiliation 'Department of Clinical and Experimental Medicine, University of Pisa, Pisa, Italy. Electronic address: alessandro.antonelli@med.unipi.it.' is academic.
# 2025-04-12 22:40:02,409 - DEBUG - Authors extracted: ['Giusy Elia']
# 2025-04-12 22:40:02,409 - DEBUG - Authors: ['Giusy Elia'] extracted.
# 2025-04-12 22:40:02,417 - DEBUG - Extracting pharma/biotech affiliations from the XML data.
# 2025-04-12 22:40:02,417 - DEBUG - Checking affiliation: Department of Clinical and Experimental Medicine, University of Pisa, Pisa, Italy. Electronic address: sm.ferrari@int.med.unipi.it.
# 2025-04-12 22:40:02,420 - DEBUG - Checking affiliation: Department of Clinical and Experimental Medicine, University of Pisa, Pisa, Italy. Electronic address: sm.ferrari@int.med.unipi.it.
# 2025-04-12 22:40:02,423 - DEBUG - Checking affiliation: Department of Clinical and Experimental Medicine, University of Pisa, Pisa, Italy. Electronic address: sm.ferrari@int.med.unipi.it.
# 2025-04-12 22:40:02,423 - DEBUG - send_request_headers.started request=<Request [b'POST']>
# 2025-04-12 22:40:02,429 - DEBUG - send_request_headers.complete
# 2025-04-12 22:40:02,430 - DEBUG - send_request_body.started request=<Request [b'POST']>
# 2025-04-12 22:40:02,432 - DEBUG - send_request_body.complete
# 2025-04-12 22:40:02,432 - DEBUG - receive_response_headers.started request=<Request [b'POST']>
# 2025-04-12 22:40:04,605 - DEBUG - receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Content-Type', b'application/json; charset=utf-8'), (b'Date', b'Sat, 12 Apr 2025 17:10:04 GMT'), (b'Content-Length', b'297')])
# 2025-04-12 22:40:04,605 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-04-12 22:40:04,607 - DEBUG - receive_response_body.started request=<Request [b'POST']>
# 2025-04-12 22:40:04,612 - DEBUG - receive_response_body.complete
# 2025-04-12 22:40:04,615 - DEBUG - response_closed.started
# 2025-04-12 22:40:04,617 - DEBUG - response_closed.complete
# 2025-04-12 22:40:04,619 - INFO - Affiliation 'Department of Clinical and Experimental Medicine, University of Pisa, Pisa, Italy. Electronic address: sm.ferrari@int.med.unipi.it.' is academic.
# 2025-04-12 22:40:04,624 - DEBUG - Checking affiliation: Department of Translational Research of New Technologies in Medicine and Surgery, University of Pisa, Pisa, Italy. Electronic address: poupak.fallahi@unipi.it.
# 2025-04-12 22:40:04,625 - DEBUG - Checking affiliation: Department of Translational Research of New Technologies in Medicine and Surgery, University of Pisa, Pisa, Italy. Electronic address: poupak.fallahi@unipi.it.
# 2025-04-12 22:40:04,627 - DEBUG - Checking affiliation: Department of Translational Research of New Technologies in Medicine and Surgery, University of Pisa, Pisa, Italy. Electronic address: poupak.fallahi@unipi.it.
# 2025-04-12 22:40:04,630 - DEBUG - send_request_headers.started request=<Request [b'POST']>
# 2025-04-12 22:40:04,636 - DEBUG - send_request_headers.complete
# 2025-04-12 22:40:04,639 - DEBUG - send_request_body.started request=<Request [b'POST']>
# 2025-04-12 22:40:04,645 - DEBUG - send_request_body.complete
# 2025-04-12 22:40:04,648 - DEBUG - receive_response_headers.started request=<Request [b'POST']>
# 2025-04-12 22:40:06,022 - DEBUG - receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Content-Type', b'application/json; charset=utf-8'), (b'Date', b'Sat, 12 Apr 2025 17:10:06 GMT'), (b'Content-Length', b'296')])
# 2025-04-12 22:40:06,022 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-04-12 22:40:06,022 - DEBUG - receive_response_body.started request=<Request [b'POST']>
# 2025-04-12 22:40:06,024 - DEBUG - receive_response_body.complete
# 2025-04-12 22:40:06,024 - DEBUG - response_closed.started
# 2025-04-12 22:40:06,024 - DEBUG - response_closed.complete
# 2025-04-12 22:40:06,024 - INFO - Affiliation 'Department of Translational Research of New Technologies in Medicine and Surgery, University of Pisa, Pisa, Italy. Electronic address: poupak.fallahi@unipi.it.' is academic.
# 2025-04-12 22:40:06,024 - DEBUG - Checking affiliation: Department of Clinical and Experimental Medicine, University of Pisa, Pisa, Italy. Electronic address: e.giusy_87@hotmail.it.
# 2025-04-12 22:40:06,024 - DEBUG - Checking affiliation: Department of Clinical and Experimental Medicine, University of Pisa, Pisa, Italy. Electronic address: e.giusy_87@hotmail.it.
# 2025-04-12 22:40:06,024 - DEBUG - Checking affiliation: Department of Clinical and Experimental Medicine, University of Pisa, Pisa, Italy. Electronic address: e.giusy_87@hotmail.it.
# 2025-04-12 22:40:06,031 - DEBUG - send_request_headers.started request=<Request [b'POST']>
# 2025-04-12 22:40:06,035 - DEBUG - send_request_headers.complete
# 2025-04-12 22:40:06,037 - DEBUG - send_request_body.started request=<Request [b'POST']>
# 2025-04-12 22:40:06,037 - DEBUG - send_request_body.complete
# 2025-04-12 22:40:06,040 - DEBUG - receive_response_headers.started request=<Request [b'POST']>
# 2025-04-12 22:40:07,163 - DEBUG - receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Content-Type', b'application/json; charset=utf-8'), (b'Date', b'Sat, 12 Apr 2025 17:10:07 GMT'), (b'Content-Length', b'294')])
# 2025-04-12 22:40:07,163 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-04-12 22:40:07,163 - DEBUG - receive_response_body.started request=<Request [b'POST']>
# 2025-04-12 22:40:07,164 - DEBUG - receive_response_body.complete
# 2025-04-12 22:40:07,165 - DEBUG - response_closed.started
# 2025-04-12 22:40:07,166 - DEBUG - response_closed.complete
# 2025-04-12 22:40:07,168 - INFO - Affiliation 'Department of Clinical and Experimental Medicine, University of Pisa, Pisa, Italy. Electronic address: e.giusy_87@hotmail.it.' is not academic.
# 2025-04-12 22:40:07,169 - INFO - Adding pharma/biotech affiliation: Department of Clinical and Experimental Medicine, University of Pisa, Pisa, Italy. Electronic address:
# 2025-04-12 22:40:07,169 - DEBUG - Checking affiliation: Department of Clinical and Experimental Medicine, University of Pisa, Pisa, Italy. Electronic address: francescaragusa86@gmail.com.
# 2025-04-12 22:40:07,169 - DEBUG - Checking affiliation: Department of Clinical and Experimental Medicine, University of Pisa, Pisa, Italy. Electronic address: francescaragusa86@gmail.com.
# 2025-04-12 22:40:07,169 - DEBUG - Checking affiliation: Department of Clinical and Experimental Medicine, University of Pisa, Pisa, Italy. Electronic address: francescaragusa86@gmail.com.
# 2025-04-12 22:40:07,169 - DEBUG - send_request_headers.started request=<Request [b'POST']>
# 2025-04-12 22:40:07,169 - DEBUG - send_request_headers.complete
# 2025-04-12 22:40:07,181 - DEBUG - send_request_body.started request=<Request [b'POST']>
# 2025-04-12 22:40:07,182 - DEBUG - send_request_body.complete
# 2025-04-12 22:40:07,183 - DEBUG - receive_response_headers.started request=<Request [b'POST']>
# 2025-04-12 22:40:08,513 - DEBUG - receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Content-Type', b'application/json; charset=utf-8'), (b'Date', b'Sat, 12 Apr 2025 17:10:08 GMT'), (b'Content-Length', b'296')])
# 2025-04-12 22:40:08,514 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-04-12 22:40:08,514 - DEBUG - receive_response_body.started request=<Request [b'POST']>
# 2025-04-12 22:40:08,514 - DEBUG - receive_response_body.complete
# 2025-04-12 22:40:08,514 - DEBUG - response_closed.started
# 2025-04-12 22:40:08,517 - DEBUG - response_closed.complete
# 2025-04-12 22:40:08,517 - INFO - Affiliation 'Department of Clinical and Experimental Medicine, University of Pisa, Pisa, Italy. Electronic address: francescaragusa86@gmail.com.' is academic.
# 2025-04-12 22:40:08,517 - DEBUG - Checking affiliation: Department of Clinical and Experimental Medicine, University of Pisa, Pisa, Italy. Electronic address: ilaria.ruffilli@gmail.com.
# 2025-04-12 22:40:08,517 - DEBUG - Checking affiliation: Department of Clinical and Experimental Medicine, University of Pisa, Pisa, Italy. Electronic address: ilaria.ruffilli@gmail.com.
# 2025-04-12 22:40:08,517 - DEBUG - Checking affiliation: Department of Clinical and Experimental Medicine, University of Pisa, Pisa, Italy. Electronic address: ilaria.ruffilli@gmail.com.
# 2025-04-12 22:40:08,517 - DEBUG - send_request_headers.started request=<Request [b'POST']>
# 2025-04-12 22:40:08,524 - DEBUG - send_request_headers.complete
# 2025-04-12 22:40:08,524 - DEBUG - send_request_body.started request=<Request [b'POST']>
# 2025-04-12 22:40:08,526 - DEBUG - send_request_body.complete
# 2025-04-12 22:40:08,527 - DEBUG - receive_response_headers.started request=<Request [b'POST']>
# 2025-04-12 22:40:09,922 - DEBUG - receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Content-Type', b'application/json; charset=utf-8'), (b'Date', b'Sat, 12 Apr 2025 17:10:09 GMT'), (b'Content-Length', b'296')])
# 2025-04-12 22:40:09,923 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-04-12 22:40:09,923 - DEBUG - receive_response_body.started request=<Request [b'POST']>
# 2025-04-12 22:40:09,929 - DEBUG - receive_response_body.complete
# 2025-04-12 22:40:09,930 - DEBUG - response_closed.started
# 2025-04-12 22:40:09,931 - DEBUG - response_closed.complete
# 2025-04-12 22:40:09,932 - INFO - Affiliation 'Department of Clinical and Experimental Medicine, University of Pisa, Pisa, Italy. Electronic address: ilaria.ruffilli@gmail.com.' is academic.
# 2025-04-12 22:40:09,934 - DEBUG - Checking affiliation: Department of Clinical and Experimental Medicine, University of Pisa, Pisa, Italy. Electronic address: sabrinapaparo@gmail.com.
# 2025-04-12 22:40:09,935 - DEBUG - Checking affiliation: Department of Clinical and Experimental Medicine, University of Pisa, Pisa, Italy. Electronic address: sabrinapaparo@gmail.com.
# 2025-04-12 22:40:09,936 - DEBUG - Checking affiliation: Department of Clinical and Experimental Medicine, University of Pisa, Pisa, Italy. Electronic address: sabrinapaparo@gmail.com.
# 2025-04-12 22:40:09,937 - DEBUG - send_request_headers.started request=<Request [b'POST']>
# 2025-04-12 22:40:09,939 - DEBUG - send_request_headers.complete
# 2025-04-12 22:40:09,940 - DEBUG - send_request_body.started request=<Request [b'POST']>
# 2025-04-12 22:40:09,942 - DEBUG - send_request_body.complete
# 2025-04-12 22:40:09,943 - DEBUG - receive_response_headers.started request=<Request [b'POST']>
# 2025-04-12 22:40:11,079 - DEBUG - receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Content-Type', b'application/json; charset=utf-8'), (b'Date', b'Sat, 12 Apr 2025 17:10:11 GMT'), (b'Content-Length', b'295')])
# 2025-04-12 22:40:11,080 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-04-12 22:40:11,080 - DEBUG - receive_response_body.started request=<Request [b'POST']>
# 2025-04-12 22:40:11,081 - DEBUG - receive_response_body.complete
# 2025-04-12 22:40:11,082 - DEBUG - response_closed.started
# 2025-04-12 22:40:11,083 - DEBUG - response_closed.complete
# 2025-04-12 22:40:11,085 - INFO - Affiliation 'Department of Clinical and Experimental Medicine, University of Pisa, Pisa, Italy. Electronic address: sabrinapaparo@gmail.com.' is academic.
# 2025-04-12 22:40:11,086 - DEBUG - Checking affiliation: Department of Clinical and Experimental Medicine, University of Pisa, Pisa, Italy. Electronic address: alessandro.antonelli@med.unipi.it.
# 2025-04-12 22:40:11,087 - DEBUG - Checking affiliation: Department of Clinical and Experimental Medicine, University of Pisa, Pisa, Italy. Electronic address: alessandro.antonelli@med.unipi.it.
# 2025-04-12 22:40:11,087 - DEBUG - Checking affiliation: Department of Clinical and Experimental Medicine, University of Pisa, Pisa, Italy. Electronic address: alessandro.antonelli@med.unipi.it.
# 2025-04-12 22:40:11,089 - DEBUG - send_request_headers.started request=<Request [b'POST']>
# 2025-04-12 22:40:11,090 - DEBUG - send_request_headers.complete
# 2025-04-12 22:40:11,091 - DEBUG - send_request_body.started request=<Request [b'POST']>
# 2025-04-12 22:40:11,092 - DEBUG - send_request_body.complete
# 2025-04-12 22:40:11,093 - DEBUG - receive_response_headers.started request=<Request [b'POST']>
# 2025-04-12 22:40:12,207 - DEBUG - receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Content-Type', b'application/json; charset=utf-8'), (b'Date', b'Sat, 12 Apr 2025 17:10:12 GMT'), (b'Content-Length', b'295')])
# 2025-04-12 22:40:12,209 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-04-12 22:40:12,209 - DEBUG - receive_response_body.started request=<Request [b'POST']>
# 2025-04-12 22:40:12,209 - DEBUG - receive_response_body.complete
# 2025-04-12 22:40:12,210 - DEBUG - response_closed.started
# 2025-04-12 22:40:12,211 - DEBUG - response_closed.complete
# 2025-04-12 22:40:12,212 - INFO - Affiliation 'Department of Clinical and Experimental Medicine, University of Pisa, Pisa, Italy. Electronic address: alessandro.antonelli@med.unipi.it.' is academic.
# 2025-04-12 22:40:12,213 - DEBUG - Pharma/Biotech affiliations extracted: ['Department of Clinical and Experimental Medicine, University of Pisa, Pisa, Italy. Electronic address:']
# 2025-04-12 22:40:12,213 - DEBUG - Company Affiliations: {'Department of Clinical and Experimental Medicine, University of Pisa, Pisa, Italy. Electronic address:'} extracted.
# 2025-04-12 22:40:12,214 - DEBUG - Extracting corresponding email from the XML data.
# 2025-04-12 22:40:12,215 - DEBUG - Checking affiliation: Department of Clinical and Experimental Medicine, University of Pisa, Pisa, Italy. Electronic address: sm.ferrari@int.med.unipi.it.
# 2025-04-12 22:40:12,216 - DEBUG - Checking affiliation: Department of Clinical and Experimental Medicine, University of Pisa, Pisa, Italy. Electronic address: sm.ferrari@int.med.unipi.it.
# 2025-04-12 22:40:12,218 - DEBUG - send_request_headers.started request=<Request [b'POST']>
# 2025-04-12 22:40:12,218 - DEBUG - send_request_headers.complete
# 2025-04-12 22:40:12,219 - DEBUG - send_request_body.started request=<Request [b'POST']>
# 2025-04-12 22:40:12,221 - DEBUG - send_request_body.complete
# 2025-04-12 22:40:12,222 - DEBUG - receive_response_headers.started request=<Request [b'POST']>
# 2025-04-12 22:40:13,748 - DEBUG - receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Content-Type', b'application/json; charset=utf-8'), (b'Date', b'Sat, 12 Apr 2025 17:10:13 GMT'), (b'Content-Length', b'296')])
# 2025-04-12 22:40:13,749 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-04-12 22:40:13,749 - DEBUG - receive_response_body.started request=<Request [b'POST']>
# 2025-04-12 22:40:13,749 - DEBUG - receive_response_body.complete
# 2025-04-12 22:40:13,749 - DEBUG - response_closed.started
# 2025-04-12 22:40:13,749 - DEBUG - response_closed.complete
# 2025-04-12 22:40:13,749 - INFO - Affiliation 'Department of Clinical and Experimental Medicine, University of Pisa, Pisa, Italy. Electronic address: sm.ferrari@int.med.unipi.it.' is academic.
# 2025-04-12 22:40:13,749 - DEBUG - Checking affiliation: Department of Translational Research of New Technologies in Medicine and Surgery, University of Pisa, Pisa, Italy. Electronic address: poupak.fallahi@unipi.it.
# 2025-04-12 22:40:13,749 - DEBUG - Checking affiliation: Department of Translational Research of New Technologies in Medicine and Surgery, University of Pisa, Pisa, Italy. Electronic address: poupak.fallahi@unipi.it.
# 2025-04-12 22:40:13,749 - DEBUG - send_request_headers.started request=<Request [b'POST']>
# 2025-04-12 22:40:13,758 - DEBUG - send_request_headers.complete
# 2025-04-12 22:40:13,758 - DEBUG - send_request_body.started request=<Request [b'POST']>
# 2025-04-12 22:40:13,759 - DEBUG - send_request_body.complete
# 2025-04-12 22:40:13,760 - DEBUG - receive_response_headers.started request=<Request [b'POST']>
# 2025-04-12 22:40:15,007 - DEBUG - receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Content-Type', b'application/json; charset=utf-8'), (b'Date', b'Sat, 12 Apr 2025 17:10:15 GMT'), (b'Content-Length', b'296')])
# 2025-04-12 22:40:15,008 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-04-12 22:40:15,008 - DEBUG - receive_response_body.started request=<Request [b'POST']>
# 2025-04-12 22:40:15,008 - DEBUG - receive_response_body.complete
# 2025-04-12 22:40:15,008 - DEBUG - response_closed.started
# 2025-04-12 22:40:15,009 - DEBUG - response_closed.complete
# 2025-04-12 22:40:15,009 - INFO - Affiliation 'Department of Translational Research of New Technologies in Medicine and Surgery, University of Pisa, Pisa, Italy. Electronic address: poupak.fallahi@unipi.it.' is academic.
# 2025-04-12 22:40:15,009 - DEBUG - Checking affiliation: Department of Clinical and Experimental Medicine, University of Pisa, Pisa, Italy. Electronic address: e.giusy_87@hotmail.it.
# 2025-04-12 22:40:15,009 - DEBUG - Checking affiliation: Department of Clinical and Experimental Medicine, University of Pisa, Pisa, Italy. Electronic address: e.giusy_87@hotmail.it.
# 2025-04-12 22:40:15,009 - DEBUG - send_request_headers.started request=<Request [b'POST']>
# 2025-04-12 22:40:15,015 - DEBUG - send_request_headers.complete
# 2025-04-12 22:40:15,016 - DEBUG - send_request_body.started request=<Request [b'POST']>
# 2025-04-12 22:40:15,017 - DEBUG - send_request_body.complete
# 2025-04-12 22:40:15,017 - DEBUG - receive_response_headers.started request=<Request [b'POST']>
# 2025-04-12 22:40:16,103 - DEBUG - receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Content-Type', b'application/json; charset=utf-8'), (b'Date', b'Sat, 12 Apr 2025 17:10:16 GMT'), (b'Content-Length', b'294')])
# 2025-04-12 22:40:16,104 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-04-12 22:40:16,107 - DEBUG - receive_response_body.started request=<Request [b'POST']>
# 2025-04-12 22:40:16,110 - DEBUG - receive_response_body.complete
# 2025-04-12 22:40:16,112 - DEBUG - response_closed.started
# 2025-04-12 22:40:16,114 - DEBUG - response_closed.complete
# 2025-04-12 22:40:16,116 - INFO - Affiliation 'Department of Clinical and Experimental Medicine, University of Pisa, Pisa, Italy. Electronic address: e.giusy_87@hotmail.it.' is not academic.
# 2025-04-12 22:40:16,118 - INFO - Adding email: e.giusy_87@hotmail.it
# 2025-04-12 22:40:16,120 - DEBUG - Checking affiliation: Department of Clinical and Experimental Medicine, University of Pisa, Pisa, Italy. Electronic address: francescaragusa86@gmail.com.
# 2025-04-12 22:40:16,121 - DEBUG - Checking affiliation: Department of Clinical and Experimental Medicine, University of Pisa, Pisa, Italy. Electronic address: francescaragusa86@gmail.com.
# 2025-04-12 22:40:16,126 - DEBUG - send_request_headers.started request=<Request [b'POST']>
# 2025-04-12 22:40:16,128 - DEBUG - send_request_headers.complete
# 2025-04-12 22:40:16,128 - DEBUG - send_request_body.started request=<Request [b'POST']>
# 2025-04-12 22:40:16,130 - DEBUG - send_request_body.complete
# 2025-04-12 22:40:16,131 - DEBUG - receive_response_headers.started request=<Request [b'POST']>
# 2025-04-12 22:40:17,442 - DEBUG - receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Content-Type', b'application/json; charset=utf-8'), (b'Date', b'Sat, 12 Apr 2025 17:10:17 GMT'), (b'Content-Length', b'296')])
# 2025-04-12 22:40:17,443 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-04-12 22:40:17,443 - DEBUG - receive_response_body.started request=<Request [b'POST']>
# 2025-04-12 22:40:17,443 - DEBUG - receive_response_body.complete
# 2025-04-12 22:40:17,443 - DEBUG - response_closed.started
# 2025-04-12 22:40:17,443 - DEBUG - response_closed.complete
# 2025-04-12 22:40:17,443 - INFO - Affiliation 'Department of Clinical and Experimental Medicine, University of Pisa, Pisa, Italy. Electronic address: francescaragusa86@gmail.com.' is academic.
# 2025-04-12 22:40:17,443 - DEBUG - Checking affiliation: Department of Clinical and Experimental Medicine, University of Pisa, Pisa, Italy. Electronic address: ilaria.ruffilli@gmail.com.
# 2025-04-12 22:40:17,443 - DEBUG - Checking affiliation: Department of Clinical and Experimental Medicine, University of Pisa, Pisa, Italy. Electronic address: ilaria.ruffilli@gmail.com.
# 2025-04-12 22:40:17,443 - DEBUG - send_request_headers.started request=<Request [b'POST']>
# 2025-04-12 22:40:17,451 - DEBUG - send_request_headers.complete
# 2025-04-12 22:40:17,451 - DEBUG - send_request_body.started request=<Request [b'POST']>
# 2025-04-12 22:40:17,453 - DEBUG - send_request_body.complete
# 2025-04-12 22:40:17,453 - DEBUG - receive_response_headers.started request=<Request [b'POST']>
# 2025-04-12 22:40:18,679 - DEBUG - receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Content-Type', b'application/json; charset=utf-8'), (b'Date', b'Sat, 12 Apr 2025 17:10:18 GMT'), (b'Content-Length', b'296')])
# 2025-04-12 22:40:18,679 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-04-12 22:40:18,679 - DEBUG - receive_response_body.started request=<Request [b'POST']>
# 2025-04-12 22:40:18,679 - DEBUG - receive_response_body.complete
# 2025-04-12 22:40:18,679 - DEBUG - response_closed.started
# 2025-04-12 22:40:18,679 - DEBUG - response_closed.complete
# 2025-04-12 22:40:18,679 - INFO - Affiliation 'Department of Clinical and Experimental Medicine, University of Pisa, Pisa, Italy. Electronic address: ilaria.ruffilli@gmail.com.' is academic.
# 2025-04-12 22:40:18,679 - DEBUG - Checking affiliation: Department of Clinical and Experimental Medicine, University of Pisa, Pisa, Italy. Electronic address: sabrinapaparo@gmail.com.
# 2025-04-12 22:40:18,679 - DEBUG - Checking affiliation: Department of Clinical and Experimental Medicine, University of Pisa, Pisa, Italy. Electronic address: sabrinapaparo@gmail.com.
# 2025-04-12 22:40:18,686 - DEBUG - send_request_headers.started request=<Request [b'POST']>
# 2025-04-12 22:40:18,688 - DEBUG - send_request_headers.complete
# 2025-04-12 22:40:18,689 - DEBUG - send_request_body.started request=<Request [b'POST']>
# 2025-04-12 22:40:18,690 - DEBUG - send_request_body.complete
# 2025-04-12 22:40:18,691 - DEBUG - receive_response_headers.started request=<Request [b'POST']>
# 2025-04-12 22:40:19,870 - DEBUG - receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Content-Type', b'application/json; charset=utf-8'), (b'Date', b'Sat, 12 Apr 2025 17:10:19 GMT'), (b'Content-Length', b'295')])
# 2025-04-12 22:40:19,870 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-04-12 22:40:19,871 - DEBUG - receive_response_body.started request=<Request [b'POST']>
# 2025-04-12 22:40:19,871 - DEBUG - receive_response_body.complete
# 2025-04-12 22:40:19,871 - DEBUG - response_closed.started
# 2025-04-12 22:40:19,871 - DEBUG - response_closed.complete
# 2025-04-12 22:40:19,871 - INFO - Affiliation 'Department of Clinical and Experimental Medicine, University of Pisa, Pisa, Italy. Electronic address: sabrinapaparo@gmail.com.' is academic.
# 2025-04-12 22:40:19,871 - DEBUG - Checking affiliation: Department of Clinical and Experimental Medicine, University of Pisa, Pisa, Italy. Electronic address: alessandro.antonelli@med.unipi.it.
# 2025-04-12 22:40:19,871 - DEBUG - Checking affiliation: Department of Clinical and Experimental Medicine, University of Pisa, Pisa, Italy. Electronic address: alessandro.antonelli@med.unipi.it.
# 2025-04-12 22:40:19,871 - DEBUG - send_request_headers.started request=<Request [b'POST']>
# 2025-04-12 22:40:19,871 - DEBUG - send_request_headers.complete
# 2025-04-12 22:40:19,871 - DEBUG - send_request_body.started request=<Request [b'POST']>
# 2025-04-12 22:40:19,871 - DEBUG - send_request_body.complete
# 2025-04-12 22:40:19,871 - DEBUG - receive_response_headers.started request=<Request [b'POST']>
# 2025-04-12 22:40:21,322 - DEBUG - receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Content-Type', b'application/json; charset=utf-8'), (b'Date', b'Sat, 12 Apr 2025 17:10:21 GMT'), (b'Content-Length', b'296')])
# 2025-04-12 22:40:21,323 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-04-12 22:40:21,323 - DEBUG - receive_response_body.started request=<Request [b'POST']>
# 2025-04-12 22:40:21,323 - DEBUG - receive_response_body.complete
# 2025-04-12 22:40:21,323 - DEBUG - response_closed.started
# 2025-04-12 22:40:21,323 - DEBUG - response_closed.complete
# 2025-04-12 22:40:21,323 - INFO - Affiliation 'Department of Clinical and Experimental Medicine, University of Pisa, Pisa, Italy. Electronic address: alessandro.antonelli@med.unipi.it.' is academic.
# 2025-04-12 22:40:21,323 - DEBUG - Corresponding Author Email: ['e.giusy_87@hotmail.it'] extracted.
# 2025-04-12 22:40:21,329 - INFO - Successfully fetched paper details for PubMed ID: 31158464
# 2025-04-12 22:40:21,331 - DEBUG - Successfully fetched details for PubMed ID: 31158464
# 2025-04-12 22:40:21,332 - INFO - Successfully fetched details for 1 papers out of 1 paper IDs.
# [{'PubMedID': '31158464',
#   'Title': 'Thyroid autoimmune disorders and cancer.',
#   'PublicationDate': 'N/A',
#   'Authors': ['Giusy Elia'],
#   'CompanyAffiliations': {'Department of Clinical and Experimental Medicine, University of Pisa, Pisa, Italy. Electronic address:'},
#   'CorrespondingAuthorEmail': ['e.giusy_87@hotmail.it']}]

# %%
import pandas as pd

# Function to save paper details to CSV
def save_paper_details_to_csv(papers: List[Dict[str, Any]], query: str, filename: Optional[str] = None) -> None:
    logging.debug(f"Starting to save paper details to CSV for query: {query}")

    # Sanitize the query to make it a valid filename
    sanitized_query = re.sub(r'[^\w\s-]', '', query)  # Remove any special characters
    sanitized_query = re.sub(r'[-\s]+', '_', sanitized_query).strip()  # Replace spaces and hyphens with underscores

    # Set the filename to the query if not provided
    if not filename:
        filename = f"{sanitized_query}_results.csv"
        logging.debug(f"Generated filename from query: {filename}")
    else:
        logging.debug(f"Using provided filename: {filename}")

    # Create a DataFrame from the list of paper details
    try:
        df = pd.DataFrame(papers)
        logging.debug(f"DataFrame created with {len(df)} rows.")

        # Save the DataFrame to a CSV file
        df.to_csv(filename, index=False, encoding='utf-8')
        logging.info(f"Results successfully saved to {filename}")
    except Exception as e:
        logging.error(f"Error saving results to {filename}: {e}")

# %%
# Save to CSV with dynamic filename based on the query
save_paper_details_to_csv(papers, query=query)
# Out:
# 2025-04-12 22:40:22,962 - DEBUG - Starting to save paper details to CSV for query: 31158464
# 2025-04-12 22:40:22,969 - DEBUG - Generated filename from query: 31158464_results.csv
# 2025-04-12 22:40:22,980 - DEBUG - DataFrame created with 1 rows.
# 2025-04-12 22:40:22,982 - INFO - Results successfully saved to 31158464_results.csv

# %%
# import sys
# import argparse
# import logging


# def setup_logging(debug: bool):
#     logging.basicConfig(
#         level=logging.DEBUG if debug else logging.INFO,
#         format='%(asctime)s - %(levelname)s - %(message)s'
#     )

# def main():
#     # Simulate command-line arguments for Jupyter Notebook
#     sys.argv = ['your_script.py', 'healthcare burnout', '--debug', '--file', 'results.csv']

#     # Argument parsing setup
#     parser = argparse.ArgumentParser(description="Fetch PubMed papers based on a query")
#     parser.add_argument("query", type=str, help="Search query to fetch papers from PubMed")
#     parser.add_argument("-d", "--debug", action="store_true", help="Enable debug logging")
#     parser.add_argument("-f", "--file", type=str, help="Specify the filename to save the results")

#     # Parse the arguments
#     args = parser.parse_args()

#     # Set up logging based on the debug flag
#     setup_logging(debug=args.debug)

#     # Fetch the papers based on the query
#     papers = fetch_all_papers(args.query, max_results=10)

#     # Save the results to a file or print them to the console
#     if args.file:
#         save_paper_details_to_csv(papers, query=args.query, filename=args.file)
#     else:
#         print(papers)

# # Run the main function
# main()
# Out:
# 2025-04-12 22:40:23,003 - DEBUG - Starting to fetch papers for query: healthcare burnout
# 2025-04-12 22:40:23,003 - DEBUG - Fetching PubMed IDs for query: healthcare burnout with parameters: {'db': 'pubmed', 'term': 'healthcare burnout', 'retmax': 10, 'usehistory': 'y', 'retmode': 'xml'}
# 2025-04-12 22:40:23,003 - DEBUG - Starting new HTTPS connection (1): eutils.ncbi.nlm.nih.gov:443
# 2025-04-12 22:40:23,927 - DEBUG - https://eutils.ncbi.nlm.nih.gov:443 "GET /entrez/eutils/esearch.fcgi?db=pubmed&term=healthcare+burnout&retmax=10&usehistory=y&retmode=xml HTTP/11" 200 None
# 2025-04-12 22:40:23,933 - INFO - Successfully fetched paper IDs for query: healthcare burnout
# 2025-04-12 22:40:23,938 - DEBUG - Fetched 10 paper IDs
# 2025-04-12 22:40:23,943 - DEBUG - Fetched 10 paper IDs for query: healthcare burnout
# 2025-04-12 22:40:23,944 - DEBUG - Fetching details for PubMed ID: 40217487
# 2025-04-12 22:40:23,946 - DEBUG - Starting to fetch paper details for PubMed ID: 40217487
# 2025-04-12 22:40:23,948 - DEBUG - Fetching XML data for PubMed ID: 40217487 with parameters: {'db': 'pubmed', 'id': '40217487', 'retmode': 'xml'}
# 2025-04-12 22:40:23,954 - DEBUG - Starting new HTTPS connection (1): eutils.ncbi.nlm.nih.gov:443
# 2025-04-12 22:40:24,786 - DEBUG - https://eutils.ncbi.nlm.nih.gov:443 "GET /entrez/eutils/efetch.fcgi?db=pubmed&id=40217487&retmode=xml HTTP/11" 200 None
# 2025-04-12 22:40:25,018 - INFO - Successfully fetched XML data for PubMed ID: 40217487
# 2025-04-12 22:40:25,025 - DEBUG - Extracting PubMed ID: 40217487
# 2025-04-12 22:40:25,025 - DEBUG - PubMed ID: 40217487 extracted.
# 2025-04-12 22:40:25,025 - INFO - Title extracted: Burnout syndrome and accidents in primary healthcare nursing workers: a scoping review.
# 2025-04-12 22:40:25,025 - DEBUG - Title: Burnout syndrome and accidents in primary healthcare nursing workers: a scoping review. extracted.
# 2025-04-12 22:40:25,025 - WARNING - Publication date not found.
# 2025-04-12 22:40:25,030 - DEBUG - Publication Date: N/A extracted.
# 2025-04-12 22:40:25,032 - DEBUG - Extracting authors from the XML data.
# 2025-04-12 22:40:25,034 - DEBUG - Processing author: Célia Cristina Franco de Godoy
# 2025-04-12 22:40:25,034 - DEBUG - Checking affiliation: Department of Public Health, Federal University of São Paulo, São Paulo, SP, Brazil.
# 2025-04-12 22:40:25,034 - DEBUG - Checking affiliation: Department of Public Health, Federal University of São Paulo, São Paulo, SP, Brazil.
# 2025-04-12 22:40:25,039 - DEBUG - send_request_headers.started request=<Request [b'POST']>
# 2025-04-12 22:40:25,041 - DEBUG - send_request_headers.complete
# 2025-04-12 22:40:25,041 - DEBUG - send_request_body.started request=<Request [b'POST']>
# 2025-04-12 22:40:25,044 - DEBUG - send_request_body.complete
# 2025-04-12 22:40:25,045 - DEBUG - receive_response_headers.started request=<Request [b'POST']>
# 2025-04-12 22:40:26,662 - DEBUG - receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Content-Type', b'application/json; charset=utf-8'), (b'Date', b'Sat, 12 Apr 2025 17:10:26 GMT'), (b'Content-Length', b'297')])
# 2025-04-12 22:40:26,663 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-04-12 22:40:26,663 - DEBUG - receive_response_body.started request=<Request [b'POST']>
# 2025-04-12 22:40:26,663 - DEBUG - receive_response_body.complete
# 2025-04-12 22:40:26,663 - DEBUG - response_closed.started
# 2025-04-12 22:40:26,663 - DEBUG - response_closed.complete
# 2025-04-12 22:40:26,663 - INFO - Affiliation 'Department of Public Health, Federal University of São Paulo, São Paulo, SP, Brazil.' is academic.
# 2025-04-12 22:40:26,663 - DEBUG - Processing author: Anacleta Rodrigues Lima
# 2025-04-12 22:40:26,669 - DEBUG - Checking affiliation: Department of Public Health, Federal University of São Paulo, São Paulo, SP, Brazil.
# 2025-04-12 22:40:26,669 - DEBUG - Checking affiliation: Department of Public Health, Federal University of São Paulo, São Paulo, SP, Brazil.
# 2025-04-12 22:40:26,669 - DEBUG - send_request_headers.started request=<Request [b'POST']>
# 2025-04-12 22:40:26,672 - DEBUG - send_request_headers.complete
# 2025-04-12 22:40:26,673 - DEBUG - send_request_body.started request=<Request [b'POST']>
# 2025-04-12 22:40:26,674 - DEBUG - send_request_body.complete
# 2025-04-12 22:40:26,674 - DEBUG - receive_response_headers.started request=<Request [b'POST']>
# 2025-04-12 22:40:27,332 - DEBUG - receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Content-Type', b'application/json; charset=utf-8'), (b'Date', b'Sat, 12 Apr 2025 17:10:27 GMT'), (b'Content-Length', b'294')])
# 2025-04-12 22:40:27,333 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-04-12 22:40:27,333 - DEBUG - receive_response_body.started request=<Request [b'POST']>
# 2025-04-12 22:40:27,333 - DEBUG - receive_response_body.complete
# 2025-04-12 22:40:27,333 - DEBUG - response_closed.started
# 2025-04-12 22:40:27,333 - DEBUG - response_closed.complete
# 2025-04-12 22:40:27,333 - INFO - Affiliation 'Department of Public Health, Federal University of São Paulo, São Paulo, SP, Brazil.' is academic.
# 2025-04-12 22:40:27,333 - DEBUG - Processing author: Paula Hino
# 2025-04-12 22:40:27,333 - DEBUG - Checking affiliation: Department of Public Health, Federal University of São Paulo, São Paulo, SP, Brazil.
# 2025-04-12 22:40:27,333 - DEBUG - Checking affiliation: Department of Public Health, Federal University of São Paulo, São Paulo, SP, Brazil.
# 2025-04-12 22:40:27,333 - DEBUG - send_request_headers.started request=<Request [b'POST']>
# 2025-04-12 22:40:27,341 - DEBUG - send_request_headers.complete
# 2025-04-12 22:40:27,341 - DEBUG - send_request_body.started request=<Request [b'POST']>
# 2025-04-12 22:40:27,343 - DEBUG - send_request_body.complete
# 2025-04-12 22:40:27,344 - DEBUG - receive_response_headers.started request=<Request [b'POST']>
# 2025-04-12 22:40:27,945 - DEBUG - receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Content-Type', b'application/json; charset=utf-8'), (b'Date', b'Sat, 12 Apr 2025 17:10:27 GMT'), (b'Content-Length', b'295')])
# 2025-04-12 22:40:27,946 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-04-12 22:40:27,946 - DEBUG - receive_response_body.started request=<Request [b'POST']>
# 2025-04-12 22:40:27,946 - DEBUG - receive_response_body.complete
# 2025-04-12 22:40:27,946 - DEBUG - response_closed.started
# 2025-04-12 22:40:27,946 - DEBUG - response_closed.complete
# 2025-04-12 22:40:27,946 - INFO - Affiliation 'Department of Public Health, Federal University of São Paulo, São Paulo, SP, Brazil.' is academic.
# 2025-04-12 22:40:27,946 - DEBUG - Processing author: Mônica Taminato
# 2025-04-12 22:40:27,946 - DEBUG - Checking affiliation: Department of Public Health, Federal University of São Paulo, São Paulo, SP, Brazil.
# 2025-04-12 22:40:27,946 - DEBUG - Checking affiliation: Department of Public Health, Federal University of São Paulo, São Paulo, SP, Brazil.
# 2025-04-12 22:40:27,946 - DEBUG - send_request_headers.started request=<Request [b'POST']>
# 2025-04-12 22:40:27,946 - DEBUG - send_request_headers.complete
# 2025-04-12 22:40:27,955 - DEBUG - send_request_body.started request=<Request [b'POST']>
# 2025-04-12 22:40:27,956 - DEBUG - send_request_body.complete
# 2025-04-12 22:40:27,957 - DEBUG - receive_response_headers.started request=<Request [b'POST']>
# 2025-04-12 22:40:28,587 - DEBUG - receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Content-Type', b'application/json; charset=utf-8'), (b'Date', b'Sat, 12 Apr 2025 17:10:28 GMT'), (b'Content-Length', b'295')])
# 2025-04-12 22:40:28,588 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-04-12 22:40:28,589 - DEBUG - receive_response_body.started request=<Request [b'POST']>
# 2025-04-12 22:40:28,589 - DEBUG - receive_response_body.complete
# 2025-04-12 22:40:28,590 - DEBUG - response_closed.started
# 2025-04-12 22:40:28,591 - DEBUG - response_closed.complete
# 2025-04-12 22:40:28,592 - INFO - Affiliation 'Department of Public Health, Federal University of São Paulo, São Paulo, SP, Brazil.' is academic.
# 2025-04-12 22:40:28,592 - DEBUG - Processing author: Meiry Fernanda Pinto Okuno
# 2025-04-12 22:40:28,592 - DEBUG - Checking affiliation: Department of Public Health, Federal University of São Paulo, São Paulo, SP, Brazil.
# 2025-04-12 22:40:28,593 - DEBUG - Checking affiliation: Department of Public Health, Federal University of São Paulo, São Paulo, SP, Brazil.
# 2025-04-12 22:40:28,594 - DEBUG - send_request_headers.started request=<Request [b'POST']>
# 2025-04-12 22:40:28,594 - DEBUG - send_request_headers.complete
# 2025-04-12 22:40:28,596 - DEBUG - send_request_body.started request=<Request [b'POST']>
# 2025-04-12 22:40:28,597 - DEBUG - send_request_body.complete
# 2025-04-12 22:40:28,597 - DEBUG - receive_response_headers.started request=<Request [b'POST']>
# 2025-04-12 22:40:29,270 - DEBUG - receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Content-Type', b'application/json; charset=utf-8'), (b'Date', b'Sat, 12 Apr 2025 17:10:29 GMT'), (b'Content-Length', b'295')])
# 2025-04-12 22:40:29,270 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-04-12 22:40:29,270 - DEBUG - receive_response_body.started request=<Request [b'POST']>
# 2025-04-12 22:40:29,270 - DEBUG - receive_response_body.complete
# 2025-04-12 22:40:29,270 - DEBUG - response_closed.started
# 2025-04-12 22:40:29,270 - DEBUG - response_closed.complete
# 2025-04-12 22:40:29,270 - INFO - Affiliation 'Department of Public Health, Federal University of São Paulo, São Paulo, SP, Brazil.' is academic.
# 2025-04-12 22:40:29,270 - DEBUG - Processing author: Hugo Fernandes
# 2025-04-12 22:40:29,270 - DEBUG - Checking affiliation: Department of Public Health, Federal University of São Paulo, São Paulo, SP, Brazil. hugo.fernandes@unifesp.br.
# 2025-04-12 22:40:29,270 - DEBUG - Checking affiliation: Department of Public Health, Federal University of São Paulo, São Paulo, SP, Brazil. hugo.fernandes@unifesp.br.
# 2025-04-12 22:40:29,270 - DEBUG - send_request_headers.started request=<Request [b'POST']>
# 2025-04-12 22:40:29,270 - DEBUG - send_request_headers.complete
# 2025-04-12 22:40:29,282 - DEBUG - send_request_body.started request=<Request [b'POST']>
# 2025-04-12 22:40:29,283 - DEBUG - send_request_body.complete
# 2025-04-12 22:40:29,284 - DEBUG - receive_response_headers.started request=<Request [b'POST']>
# 2025-04-12 22:40:31,265 - DEBUG - receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Content-Type', b'application/json; charset=utf-8'), (b'Date', b'Sat, 12 Apr 2025 17:10:31 GMT'), (b'Content-Length', b'296')])
# 2025-04-12 22:40:31,265 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-04-12 22:40:31,266 - DEBUG - receive_response_body.started request=<Request [b'POST']>
# 2025-04-12 22:40:31,266 - DEBUG - receive_response_body.complete
# 2025-04-12 22:40:31,267 - DEBUG - response_closed.started
# 2025-04-12 22:40:31,267 - DEBUG - response_closed.complete
# 2025-04-12 22:40:31,267 - INFO - Affiliation 'Department of Public Health, Federal University of São Paulo, São Paulo, SP, Brazil. hugo.fernandes@unifesp.br.' is academic.
# 2025-04-12 22:40:31,268 - DEBUG - No authors found.
# 2025-04-12 22:40:31,269 - DEBUG - Authors: ['N/A'] extracted.
# 2025-04-12 22:40:31,269 - DEBUG - Extracting pharma/biotech affiliations from the XML data.
# 2025-04-12 22:40:31,269 - DEBUG - Checking affiliation: Department of Public Health, Federal University of São Paulo, São Paulo, SP, Brazil.
# 2025-04-12 22:40:31,269 - DEBUG - Checking affiliation: Department of Public Health, Federal University of São Paulo, São Paulo, SP, Brazil.
# 2025-04-12 22:40:31,269 - INFO - Affiliation is not related to pharma/biotech: Department of Public Health, Federal University of São Paulo, São Paulo, SP, Brazil.
# 2025-04-12 22:40:31,270 - DEBUG - Checking affiliation: Department of Public Health, Federal University of São Paulo, São Paulo, SP, Brazil.
# 2025-04-12 22:40:31,271 - DEBUG - Checking affiliation: Department of Public Health, Federal University of São Paulo, São Paulo, SP, Brazil.
# 2025-04-12 22:40:31,271 - INFO - Affiliation is not related to pharma/biotech: Department of Public Health, Federal University of São Paulo, São Paulo, SP, Brazil.
# 2025-04-12 22:40:31,271 - DEBUG - Checking affiliation: Department of Public Health, Federal University of São Paulo, São Paulo, SP, Brazil.
# 2025-04-12 22:40:31,271 - DEBUG - Checking affiliation: Department of Public Health, Federal University of São Paulo, São Paulo, SP, Brazil.
# 2025-04-12 22:40:31,271 - INFO - Affiliation is not related to pharma/biotech: Department of Public Health, Federal University of São Paulo, São Paulo, SP, Brazil.
# 2025-04-12 22:40:31,272 - DEBUG - Checking affiliation: Department of Public Health, Federal University of São Paulo, São Paulo, SP, Brazil.
# 2025-04-12 22:40:31,273 - DEBUG - Checking affiliation: Department of Public Health, Federal University of São Paulo, São Paulo, SP, Brazil.
# 2025-04-12 22:40:31,273 - INFO - Affiliation is not related to pharma/biotech: Department of Public Health, Federal University of São Paulo, São Paulo, SP, Brazil.
# 2025-04-12 22:40:31,273 - DEBUG - Checking affiliation: Department of Public Health, Federal University of São Paulo, São Paulo, SP, Brazil.
# 2025-04-12 22:40:31,273 - DEBUG - Checking affiliation: Department of Public Health, Federal University of São Paulo, São Paulo, SP, Brazil.
# 2025-04-12 22:40:31,273 - INFO - Affiliation is not related to pharma/biotech: Department of Public Health, Federal University of São Paulo, São Paulo, SP, Brazil.
# 2025-04-12 22:40:31,273 - DEBUG - Checking affiliation: Department of Public Health, Federal University of São Paulo, São Paulo, SP, Brazil. hugo.fernandes@unifesp.br.
# 2025-04-12 22:40:31,273 - DEBUG - Checking affiliation: Department of Public Health, Federal University of São Paulo, São Paulo, SP, Brazil. hugo.fernandes@unifesp.br.
# 2025-04-12 22:40:31,273 - INFO - Affiliation is not related to pharma/biotech: Department of Public Health, Federal University of São Paulo, São Paulo, SP, Brazil. hugo.fernandes@unifesp.br.
# 2025-04-12 22:40:31,273 - DEBUG - No pharma/biotech affiliations found.
# 2025-04-12 22:40:31,273 - DEBUG - Company Affiliations: ['N/A'] extracted.
# 2025-04-12 22:40:31,273 - DEBUG - Extracting corresponding email from the XML data.
# 2025-04-12 22:40:31,273 - DEBUG - Checking affiliation: Department of Public Health, Federal University of São Paulo, São Paulo, SP, Brazil.
# 2025-04-12 22:40:31,273 - DEBUG - Checking affiliation: Department of Public Health, Federal University of São Paulo, São Paulo, SP, Brazil.
# 2025-04-12 22:40:31,273 - DEBUG - send_request_headers.started request=<Request [b'POST']>
# 2025-04-12 22:40:31,280 - DEBUG - send_request_headers.complete
# 2025-04-12 22:40:31,280 - DEBUG - send_request_body.started request=<Request [b'POST']>
# 2025-04-12 22:40:31,282 - DEBUG - send_request_body.complete
# 2025-04-12 22:40:31,282 - DEBUG - receive_response_headers.started request=<Request [b'POST']>
# 2025-04-12 22:40:32,678 - DEBUG - receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Content-Type', b'application/json; charset=utf-8'), (b'Date', b'Sat, 12 Apr 2025 17:10:32 GMT'), (b'Content-Length', b'297')])
# 2025-04-12 22:40:32,678 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-04-12 22:40:32,678 - DEBUG - receive_response_body.started request=<Request [b'POST']>
# 2025-04-12 22:40:32,678 - DEBUG - receive_response_body.complete
# 2025-04-12 22:40:32,678 - DEBUG - response_closed.started
# 2025-04-12 22:40:32,678 - DEBUG - response_closed.complete
# 2025-04-12 22:40:32,678 - INFO - Affiliation 'Department of Public Health, Federal University of São Paulo, São Paulo, SP, Brazil.' is academic.
# 2025-04-12 22:40:32,678 - DEBUG - Checking affiliation: Department of Public Health, Federal University of São Paulo, São Paulo, SP, Brazil.
# 2025-04-12 22:40:32,678 - DEBUG - Checking affiliation: Department of Public Health, Federal University of São Paulo, São Paulo, SP, Brazil.
# 2025-04-12 22:40:32,678 - DEBUG - send_request_headers.started request=<Request [b'POST']>
# 2025-04-12 22:40:32,689 - DEBUG - send_request_headers.complete
# 2025-04-12 22:40:32,690 - DEBUG - send_request_body.started request=<Request [b'POST']>
# 2025-04-12 22:40:32,691 - DEBUG - send_request_body.complete
# 2025-04-12 22:40:32,692 - DEBUG - receive_response_headers.started request=<Request [b'POST']>
# 2025-04-12 22:40:33,332 - DEBUG - receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Content-Type', b'application/json; charset=utf-8'), (b'Date', b'Sat, 12 Apr 2025 17:10:33 GMT'), (b'Content-Length', b'295')])
# 2025-04-12 22:40:33,333 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-04-12 22:40:33,333 - DEBUG - receive_response_body.started request=<Request [b'POST']>
# 2025-04-12 22:40:33,333 - DEBUG - receive_response_body.complete
# 2025-04-12 22:40:33,333 - DEBUG - response_closed.started
# 2025-04-12 22:40:33,333 - DEBUG - response_closed.complete
# 2025-04-12 22:40:33,338 - INFO - Affiliation 'Department of Public Health, Federal University of São Paulo, São Paulo, SP, Brazil.' is academic.
# 2025-04-12 22:40:33,338 - DEBUG - Checking affiliation: Department of Public Health, Federal University of São Paulo, São Paulo, SP, Brazil.
# 2025-04-12 22:40:33,338 - DEBUG - Checking affiliation: Department of Public Health, Federal University of São Paulo, São Paulo, SP, Brazil.
# 2025-04-12 22:40:33,338 - DEBUG - send_request_headers.started request=<Request [b'POST']>
# 2025-04-12 22:40:33,344 - DEBUG - send_request_headers.complete
# 2025-04-12 22:40:33,344 - DEBUG - send_request_body.started request=<Request [b'POST']>
# 2025-04-12 22:40:33,347 - DEBUG - send_request_body.complete
# 2025-04-12 22:40:33,348 - DEBUG - receive_response_headers.started request=<Request [b'POST']>
# 2025-04-12 22:40:34,005 - DEBUG - receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Content-Type', b'application/json; charset=utf-8'), (b'Date', b'Sat, 12 Apr 2025 17:10:34 GMT'), (b'Content-Length', b'295')])
# 2025-04-12 22:40:34,006 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-04-12 22:40:34,006 - DEBUG - receive_response_body.started request=<Request [b'POST']>
# 2025-04-12 22:40:34,006 - DEBUG - receive_response_body.complete
# 2025-04-12 22:40:34,006 - DEBUG - response_closed.started
# 2025-04-12 22:40:34,006 - DEBUG - response_closed.complete
# 2025-04-12 22:40:34,006 - INFO - Affiliation 'Department of Public Health, Federal University of São Paulo, São Paulo, SP, Brazil.' is academic.
# 2025-04-12 22:40:34,006 - DEBUG - Checking affiliation: Department of Public Health, Federal University of São Paulo, São Paulo, SP, Brazil.
# 2025-04-12 22:40:34,006 - DEBUG - Checking affiliation: Department of Public Health, Federal University of São Paulo, São Paulo, SP, Brazil.
# 2025-04-12 22:40:34,006 - DEBUG - send_request_headers.started request=<Request [b'POST']>
# 2025-04-12 22:40:34,015 - DEBUG - send_request_headers.complete
# 2025-04-12 22:40:34,015 - DEBUG - send_request_body.started request=<Request [b'POST']>
# 2025-04-12 22:40:34,015 - DEBUG - send_request_body.complete
# 2025-04-12 22:40:34,017 - DEBUG - receive_response_headers.started request=<Request [b'POST']>
# 2025-04-12 22:40:34,640 - DEBUG - receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Content-Type', b'application/json; charset=utf-8'), (b'Date', b'Sat, 12 Apr 2025 17:10:34 GMT'), (b'Content-Length', b'295')])
# 2025-04-12 22:40:34,641 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-04-12 22:40:34,641 - DEBUG - receive_response_body.started request=<Request [b'POST']>
# 2025-04-12 22:40:34,641 - DEBUG - receive_response_body.complete
# 2025-04-12 22:40:34,641 - DEBUG - response_closed.started
# 2025-04-12 22:40:34,641 - DEBUG - response_closed.complete
# 2025-04-12 22:40:34,641 - INFO - Affiliation 'Department of Public Health, Federal University of São Paulo, São Paulo, SP, Brazil.' is academic.
# 2025-04-12 22:40:34,641 - DEBUG - Checking affiliation: Department of Public Health, Federal University of São Paulo, São Paulo, SP, Brazil.
# 2025-04-12 22:40:34,641 - DEBUG - Checking affiliation: Department of Public Health, Federal University of São Paulo, São Paulo, SP, Brazil.
# 2025-04-12 22:40:34,641 - DEBUG - send_request_headers.started request=<Request [b'POST']>
# 2025-04-12 22:40:34,641 - DEBUG - send_request_headers.complete
# 2025-04-12 22:40:34,650 - DEBUG - send_request_body.started request=<Request [b'POST']>
# 2025-04-12 22:40:34,651 - DEBUG - send_request_body.complete
# 2025-04-12 22:40:34,652 - DEBUG - receive_response_headers.started request=<Request [b'POST']>
# 2025-04-12 22:40:35,272 - DEBUG - receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Content-Type', b'application/json; charset=utf-8'), (b'Date', b'Sat, 12 Apr 2025 17:10:35 GMT'), (b'Content-Length', b'295')])
# 2025-04-12 22:40:35,272 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-04-12 22:40:35,272 - DEBUG - receive_response_body.started request=<Request [b'POST']>
# 2025-04-12 22:40:35,272 - DEBUG - receive_response_body.complete
# 2025-04-12 22:40:35,272 - DEBUG - response_closed.started
# 2025-04-12 22:40:35,272 - DEBUG - response_closed.complete
# 2025-04-12 22:40:35,272 - INFO - Affiliation 'Department of Public Health, Federal University of São Paulo, São Paulo, SP, Brazil.' is academic.
# 2025-04-12 22:40:35,272 - DEBUG - Checking affiliation: Department of Public Health, Federal University of São Paulo, São Paulo, SP, Brazil. hugo.fernandes@unifesp.br.
# 2025-04-12 22:40:35,272 - DEBUG - Checking affiliation: Department of Public Health, Federal University of São Paulo, São Paulo, SP, Brazil. hugo.fernandes@unifesp.br.
# 2025-04-12 22:40:35,272 - DEBUG - send_request_headers.started request=<Request [b'POST']>
# 2025-04-12 22:40:35,282 - DEBUG - send_request_headers.complete
# 2025-04-12 22:40:35,282 - DEBUG - send_request_body.started request=<Request [b'POST']>
# 2025-04-12 22:40:35,284 - DEBUG - send_request_body.complete
# 2025-04-12 22:40:35,285 - DEBUG - receive_response_headers.started request=<Request [b'POST']>
# 2025-04-12 22:40:36,996 - DEBUG - receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Content-Type', b'application/json; charset=utf-8'), (b'Date', b'Sat, 12 Apr 2025 17:10:36 GMT'), (b'Content-Length', b'297')])
# 2025-04-12 22:40:36,997 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-04-12 22:40:36,997 - DEBUG - receive_response_body.started request=<Request [b'POST']>
# 2025-04-12 22:40:36,998 - DEBUG - receive_response_body.complete
# 2025-04-12 22:40:36,998 - DEBUG - response_closed.started
# 2025-04-12 22:40:36,999 - DEBUG - response_closed.complete
# 2025-04-12 22:40:37,000 - INFO - Affiliation 'Department of Public Health, Federal University of São Paulo, São Paulo, SP, Brazil. hugo.fernandes@unifesp.br.' is academic.
# 2025-04-12 22:40:37,001 - DEBUG - Corresponding Author Email: ['N/A'] extracted.
# 2025-04-12 22:40:37,001 - INFO - Successfully fetched paper details for PubMed ID: 40217487
# 2025-04-12 22:40:37,002 - DEBUG - Successfully fetched details for PubMed ID: 40217487
# 2025-04-12 22:40:37,002 - DEBUG - Fetching details for PubMed ID: 40217285
# 2025-04-12 22:40:37,003 - DEBUG - Starting to fetch paper details for PubMed ID: 40217285
# 2025-04-12 22:40:37,004 - DEBUG - Fetching XML data for PubMed ID: 40217285 with parameters: {'db': 'pubmed', 'id': '40217285', 'retmode': 'xml'}
# 2025-04-12 22:40:37,006 - DEBUG - Starting new HTTPS connection (1): eutils.ncbi.nlm.nih.gov:443
# 2025-04-12 22:40:37,773 - DEBUG - https://eutils.ncbi.nlm.nih.gov:443 "GET /entrez/eutils/efetch.fcgi?db=pubmed&id=40217285&retmode=xml HTTP/11" 200 None
# 2025-04-12 22:40:38,017 - INFO - Successfully fetched XML data for PubMed ID: 40217285
# 2025-04-12 22:40:38,017 - DEBUG - Extracting PubMed ID: 40217285
# 2025-04-12 22:40:38,017 - DEBUG - PubMed ID: 40217285 extracted.
# 2025-04-12 22:40:38,017 - INFO - Title extracted: Digital stress perception and associations with work- and health-related outcomes among general practitioners in Germany: a quantitative study.
# 2025-04-12 22:40:38,017 - DEBUG - Title: Digital stress perception and associations with work- and health-related outcomes among general practitioners in Germany: a quantitative study. extracted.
# 2025-04-12 22:40:38,017 - WARNING - Publication date not found.
# 2025-04-12 22:40:38,017 - DEBUG - Publication Date: N/A extracted.
# 2025-04-12 22:40:38,017 - DEBUG - Extracting authors from the XML data.
# 2025-04-12 22:40:38,017 - DEBUG - Processing author: Annika Würtenberger
# 2025-04-12 22:40:38,017 - DEBUG - Checking affiliation: Institute for Occupational and Maritime Medicine (ZfAM), University Medical Center Hamburg-Eppendorf (UKE), Hamburg, 20459, Germany.
# 2025-04-12 22:40:38,017 - DEBUG - Checking affiliation: Institute for Occupational and Maritime Medicine (ZfAM), University Medical Center Hamburg-Eppendorf (UKE), Hamburg, 20459, Germany.
# 2025-04-12 22:40:38,017 - DEBUG - send_request_headers.started request=<Request [b'POST']>
# 2025-04-12 22:40:38,017 - DEBUG - send_request_headers.complete
# 2025-04-12 22:40:38,033 - DEBUG - send_request_body.started request=<Request [b'POST']>
# 2025-04-12 22:40:38,034 - DEBUG - send_request_body.complete
# 2025-04-12 22:40:38,035 - DEBUG - receive_response_headers.started request=<Request [b'POST']>
# 2025-04-12 22:40:39,273 - DEBUG - receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Content-Type', b'application/json; charset=utf-8'), (b'Date', b'Sat, 12 Apr 2025 17:10:39 GMT'), (b'Content-Length', b'296')])
# 2025-04-12 22:40:39,274 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-04-12 22:40:39,274 - DEBUG - receive_response_body.started request=<Request [b'POST']>
# 2025-04-12 22:40:39,274 - DEBUG - receive_response_body.complete
# 2025-04-12 22:40:39,274 - DEBUG - response_closed.started
# 2025-04-12 22:40:39,274 - DEBUG - response_closed.complete
# 2025-04-12 22:40:39,274 - INFO - Affiliation 'Institute for Occupational and Maritime Medicine (ZfAM), University Medical Center Hamburg-Eppendorf (UKE), Hamburg, 20459, Germany.' is academic.
# 2025-04-12 22:40:39,274 - DEBUG - Checking affiliation: Institute of Occupational Medicine, Social Medicine and Environmental Medicine, Goethe University Frankfurt, Frankfurt, 60590, Germany.
# 2025-04-12 22:40:39,274 - DEBUG - Checking affiliation: Institute of Occupational Medicine, Social Medicine and Environmental Medicine, Goethe University Frankfurt, Frankfurt, 60590, Germany.
# 2025-04-12 22:40:39,274 - DEBUG - send_request_headers.started request=<Request [b'POST']>
# 2025-04-12 22:40:39,281 - DEBUG - send_request_headers.complete
# 2025-04-12 22:40:39,282 - DEBUG - send_request_body.started request=<Request [b'POST']>
# 2025-04-12 22:40:39,283 - DEBUG - send_request_body.complete
# 2025-04-12 22:40:39,283 - DEBUG - receive_response_headers.started request=<Request [b'POST']>
# 2025-04-12 22:40:40,540 - DEBUG - receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Content-Type', b'application/json; charset=utf-8'), (b'Date', b'Sat, 12 Apr 2025 17:10:40 GMT'), (b'Content-Length', b'296')])
# 2025-04-12 22:40:40,541 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-04-12 22:40:40,541 - DEBUG - receive_response_body.started request=<Request [b'POST']>
# 2025-04-12 22:40:40,541 - DEBUG - receive_response_body.complete
# 2025-04-12 22:40:40,541 - DEBUG - response_closed.started
# 2025-04-12 22:40:40,541 - DEBUG - response_closed.complete
# 2025-04-12 22:40:40,541 - INFO - Affiliation 'Institute of Occupational Medicine, Social Medicine and Environmental Medicine, Goethe University Frankfurt, Frankfurt, 60590, Germany.' is academic.
# 2025-04-12 22:40:40,541 - DEBUG - Processing author: David A Groneberg
# 2025-04-12 22:40:40,541 - DEBUG - Checking affiliation: Institute of Occupational Medicine, Social Medicine and Environmental Medicine, Goethe University Frankfurt, Frankfurt, 60590, Germany.
# 2025-04-12 22:40:40,541 - DEBUG - Checking affiliation: Institute of Occupational Medicine, Social Medicine and Environmental Medicine, Goethe University Frankfurt, Frankfurt, 60590, Germany.
# 2025-04-12 22:40:40,541 - DEBUG - send_request_headers.started request=<Request [b'POST']>
# 2025-04-12 22:40:40,550 - DEBUG - send_request_headers.complete
# 2025-04-12 22:40:40,551 - DEBUG - send_request_body.started request=<Request [b'POST']>
# 2025-04-12 22:40:40,552 - DEBUG - send_request_body.complete
# 2025-04-12 22:40:40,553 - DEBUG - receive_response_headers.started request=<Request [b'POST']>
# 2025-04-12 22:40:41,105 - DEBUG - receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Content-Type', b'application/json; charset=utf-8'), (b'Date', b'Sat, 12 Apr 2025 17:10:41 GMT'), (b'Content-Length', b'295')])
# 2025-04-12 22:40:41,106 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-04-12 22:40:41,106 - DEBUG - receive_response_body.started request=<Request [b'POST']>
# 2025-04-12 22:40:41,106 - DEBUG - receive_response_body.complete
# 2025-04-12 22:40:41,106 - DEBUG - response_closed.started
# 2025-04-12 22:40:41,106 - DEBUG - response_closed.complete
# 2025-04-12 22:40:41,106 - INFO - Affiliation 'Institute of Occupational Medicine, Social Medicine and Environmental Medicine, Goethe University Frankfurt, Frankfurt, 60590, Germany.' is academic.
# 2025-04-12 22:40:41,106 - DEBUG - Processing author: Stefanie Mache
# 2025-04-12 22:40:41,106 - DEBUG - Checking affiliation: Institute for Occupational and Maritime Medicine (ZfAM), University Medical Center Hamburg-Eppendorf (UKE), Hamburg, 20459, Germany. s.mache@uke.de.
# 2025-04-12 22:40:41,106 - DEBUG - Checking affiliation: Institute for Occupational and Maritime Medicine (ZfAM), University Medical Center Hamburg-Eppendorf (UKE), Hamburg, 20459, Germany. s.mache@uke.de.
# 2025-04-12 22:40:41,106 - DEBUG - send_request_headers.started request=<Request [b'POST']>
# 2025-04-12 22:40:41,106 - DEBUG - send_request_headers.complete
# 2025-04-12 22:40:41,115 - DEBUG - send_request_body.started request=<Request [b'POST']>
# 2025-04-12 22:40:41,117 - DEBUG - send_request_body.complete
# 2025-04-12 22:40:41,117 - DEBUG - receive_response_headers.started request=<Request [b'POST']>
# 2025-04-12 22:40:42,498 - DEBUG - receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Content-Type', b'application/json; charset=utf-8'), (b'Date', b'Sat, 12 Apr 2025 17:10:42 GMT'), (b'Content-Length', b'297')])
# 2025-04-12 22:40:42,499 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-04-12 22:40:42,499 - DEBUG - receive_response_body.started request=<Request [b'POST']>
# 2025-04-12 22:40:42,499 - DEBUG - receive_response_body.complete
# 2025-04-12 22:40:42,499 - DEBUG - response_closed.started
# 2025-04-12 22:40:42,499 - DEBUG - response_closed.complete
# 2025-04-12 22:40:42,499 - INFO - Affiliation 'Institute for Occupational and Maritime Medicine (ZfAM), University Medical Center Hamburg-Eppendorf (UKE), Hamburg, 20459, Germany. s.mache@uke.de.' is academic.
# 2025-04-12 22:40:42,499 - DEBUG - Checking affiliation: Institute of Occupational Medicine, Social Medicine and Environmental Medicine, Goethe University Frankfurt, Frankfurt, 60590, Germany. s.mache@uke.de.
# 2025-04-12 22:40:42,499 - DEBUG - Checking affiliation: Institute of Occupational Medicine, Social Medicine and Environmental Medicine, Goethe University Frankfurt, Frankfurt, 60590, Germany. s.mache@uke.de.
# 2025-04-12 22:40:42,499 - DEBUG - send_request_headers.started request=<Request [b'POST']>
# 2025-04-12 22:40:42,506 - DEBUG - send_request_headers.complete
# 2025-04-12 22:40:42,506 - DEBUG - send_request_body.started request=<Request [b'POST']>
# 2025-04-12 22:40:42,507 - DEBUG - send_request_body.complete
# 2025-04-12 22:40:42,507 - DEBUG - receive_response_headers.started request=<Request [b'POST']>
# 2025-04-12 22:40:43,569 - DEBUG - receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Content-Type', b'application/json; charset=utf-8'), (b'Date', b'Sat, 12 Apr 2025 17:10:43 GMT'), (b'Content-Length', b'295')])
# 2025-04-12 22:40:43,570 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-04-12 22:40:43,570 - DEBUG - receive_response_body.started request=<Request [b'POST']>
# 2025-04-12 22:40:43,570 - DEBUG - receive_response_body.complete
# 2025-04-12 22:40:43,570 - DEBUG - response_closed.started
# 2025-04-12 22:40:43,570 - DEBUG - response_closed.complete
# 2025-04-12 22:40:43,570 - INFO - Affiliation 'Institute of Occupational Medicine, Social Medicine and Environmental Medicine, Goethe University Frankfurt, Frankfurt, 60590, Germany. s.mache@uke.de.' is academic.
# 2025-04-12 22:40:43,570 - DEBUG - No authors found.
# 2025-04-12 22:40:43,570 - DEBUG - Authors: ['N/A'] extracted.
# 2025-04-12 22:40:43,570 - DEBUG - Extracting pharma/biotech affiliations from the XML data.
# 2025-04-12 22:40:43,570 - DEBUG - Checking affiliation: Institute for Occupational and Maritime Medicine (ZfAM), University Medical Center Hamburg-Eppendorf (UKE), Hamburg, 20459, Germany.
# 2025-04-12 22:40:43,570 - DEBUG - Checking affiliation: Institute for Occupational and Maritime Medicine (ZfAM), University Medical Center Hamburg-Eppendorf (UKE), Hamburg, 20459, Germany.
# 2025-04-12 22:40:43,570 - DEBUG - Checking affiliation: Institute for Occupational and Maritime Medicine (ZfAM), University Medical Center Hamburg-Eppendorf (UKE), Hamburg, 20459, Germany.
# 2025-04-12 22:40:43,570 - DEBUG - send_request_headers.started request=<Request [b'POST']>
# 2025-04-12 22:40:43,580 - DEBUG - send_request_headers.complete
# 2025-04-12 22:40:43,580 - DEBUG - send_request_body.started request=<Request [b'POST']>
# 2025-04-12 22:40:43,582 - DEBUG - send_request_body.complete
# 2025-04-12 22:40:43,583 - DEBUG - receive_response_headers.started request=<Request [b'POST']>
# 2025-04-12 22:40:44,888 - DEBUG - receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Content-Type', b'application/json; charset=utf-8'), (b'Date', b'Sat, 12 Apr 2025 17:10:44 GMT'), (b'Content-Length', b'296')])
# 2025-04-12 22:40:44,888 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-04-12 22:40:44,888 - DEBUG - receive_response_body.started request=<Request [b'POST']>
# 2025-04-12 22:40:44,888 - DEBUG - receive_response_body.complete
# 2025-04-12 22:40:44,888 - DEBUG - response_closed.started
# 2025-04-12 22:40:44,888 - DEBUG - response_closed.complete
# 2025-04-12 22:40:44,888 - INFO - Affiliation 'Institute for Occupational and Maritime Medicine (ZfAM), University Medical Center Hamburg-Eppendorf (UKE), Hamburg, 20459, Germany.' is academic.
# 2025-04-12 22:40:44,888 - DEBUG - Checking affiliation: Institute of Occupational Medicine, Social Medicine and Environmental Medicine, Goethe University Frankfurt, Frankfurt, 60590, Germany.
# 2025-04-12 22:40:44,888 - DEBUG - Checking affiliation: Institute of Occupational Medicine, Social Medicine and Environmental Medicine, Goethe University Frankfurt, Frankfurt, 60590, Germany.
# 2025-04-12 22:40:44,888 - DEBUG - Checking affiliation: Institute of Occupational Medicine, Social Medicine and Environmental Medicine, Goethe University Frankfurt, Frankfurt, 60590, Germany.
# 2025-04-12 22:40:44,888 - DEBUG - send_request_headers.started request=<Request [b'POST']>
# 2025-04-12 22:40:44,896 - DEBUG - send_request_headers.complete
# 2025-04-12 22:40:44,896 - DEBUG - send_request_body.started request=<Request [b'POST']>
# 2025-04-12 22:40:44,898 - DEBUG - send_request_body.complete
# 2025-04-12 22:40:44,899 - DEBUG - receive_response_headers.started request=<Request [b'POST']>
# 2025-04-12 22:40:46,114 - DEBUG - receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Content-Type', b'application/json; charset=utf-8'), (b'Date', b'Sat, 12 Apr 2025 17:10:46 GMT'), (b'Content-Length', b'296')])
# 2025-04-12 22:40:46,114 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-04-12 22:40:46,114 - DEBUG - receive_response_body.started request=<Request [b'POST']>
# 2025-04-12 22:40:46,114 - DEBUG - receive_response_body.complete
# 2025-04-12 22:40:46,114 - DEBUG - response_closed.started
# 2025-04-12 22:40:46,117 - DEBUG - response_closed.complete
# 2025-04-12 22:40:46,117 - INFO - Affiliation 'Institute of Occupational Medicine, Social Medicine and Environmental Medicine, Goethe University Frankfurt, Frankfurt, 60590, Germany.' is academic.
# 2025-04-12 22:40:46,117 - DEBUG - Checking affiliation: Institute of Occupational Medicine, Social Medicine and Environmental Medicine, Goethe University Frankfurt, Frankfurt, 60590, Germany.
# 2025-04-12 22:40:46,117 - DEBUG - Checking affiliation: Institute of Occupational Medicine, Social Medicine and Environmental Medicine, Goethe University Frankfurt, Frankfurt, 60590, Germany.
# 2025-04-12 22:40:46,117 - DEBUG - Checking affiliation: Institute of Occupational Medicine, Social Medicine and Environmental Medicine, Goethe University Frankfurt, Frankfurt, 60590, Germany.
# 2025-04-12 22:40:46,117 - DEBUG - send_request_headers.started request=<Request [b'POST']>
# 2025-04-12 22:40:46,117 - DEBUG - send_request_headers.complete
# 2025-04-12 22:40:46,123 - DEBUG - send_request_body.started request=<Request [b'POST']>
# 2025-04-12 22:40:46,124 - DEBUG - send_request_body.complete
# 2025-04-12 22:40:46,125 - DEBUG - receive_response_headers.started request=<Request [b'POST']>
# 2025-04-12 22:40:46,883 - DEBUG - receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Content-Type', b'application/json; charset=utf-8'), (b'Date', b'Sat, 12 Apr 2025 17:10:46 GMT'), (b'Content-Length', b'294')])
# 2025-04-12 22:40:46,883 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-04-12 22:40:46,883 - DEBUG - receive_response_body.started request=<Request [b'POST']>
# 2025-04-12 22:40:46,883 - DEBUG - receive_response_body.complete
# 2025-04-12 22:40:46,883 - DEBUG - response_closed.started
# 2025-04-12 22:40:46,883 - DEBUG - response_closed.complete
# 2025-04-12 22:40:46,883 - INFO - Affiliation 'Institute of Occupational Medicine, Social Medicine and Environmental Medicine, Goethe University Frankfurt, Frankfurt, 60590, Germany.' is academic.
# 2025-04-12 22:40:46,883 - DEBUG - Checking affiliation: Institute for Occupational and Maritime Medicine (ZfAM), University Medical Center Hamburg-Eppendorf (UKE), Hamburg, 20459, Germany. s.mache@uke.de.
# 2025-04-12 22:40:46,883 - DEBUG - Checking affiliation: Institute for Occupational and Maritime Medicine (ZfAM), University Medical Center Hamburg-Eppendorf (UKE), Hamburg, 20459, Germany. s.mache@uke.de.
# 2025-04-12 22:40:46,883 - DEBUG - Checking affiliation: Institute for Occupational and Maritime Medicine (ZfAM), University Medical Center Hamburg-Eppendorf (UKE), Hamburg, 20459, Germany. s.mache@uke.de.
# 2025-04-12 22:40:46,893 - DEBUG - send_request_headers.started request=<Request [b'POST']>
# 2025-04-12 22:40:46,896 - DEBUG - send_request_headers.complete
# 2025-04-12 22:40:46,896 - DEBUG - send_request_body.started request=<Request [b'POST']>
# 2025-04-12 22:40:46,897 - DEBUG - send_request_body.complete
# 2025-04-12 22:40:46,898 - DEBUG - receive_response_headers.started request=<Request [b'POST']>
# 2025-04-12 22:40:48,169 - DEBUG - receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Content-Type', b'application/json; charset=utf-8'), (b'Date', b'Sat, 12 Apr 2025 17:10:48 GMT'), (b'Content-Length', b'296')])
# 2025-04-12 22:40:48,169 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-04-12 22:40:48,169 - DEBUG - receive_response_body.started request=<Request [b'POST']>
# 2025-04-12 22:40:48,169 - DEBUG - receive_response_body.complete
# 2025-04-12 22:40:48,169 - DEBUG - response_closed.started
# 2025-04-12 22:40:48,169 - DEBUG - response_closed.complete
# 2025-04-12 22:40:48,169 - INFO - Affiliation 'Institute for Occupational and Maritime Medicine (ZfAM), University Medical Center Hamburg-Eppendorf (UKE), Hamburg, 20459, Germany. s.mache@uke.de.' is academic.
# 2025-04-12 22:40:48,169 - DEBUG - Checking affiliation: Institute of Occupational Medicine, Social Medicine and Environmental Medicine, Goethe University Frankfurt, Frankfurt, 60590, Germany. s.mache@uke.de.
# 2025-04-12 22:40:48,169 - DEBUG - Checking affiliation: Institute of Occupational Medicine, Social Medicine and Environmental Medicine, Goethe University Frankfurt, Frankfurt, 60590, Germany. s.mache@uke.de.
# 2025-04-12 22:40:48,169 - DEBUG - Checking affiliation: Institute of Occupational Medicine, Social Medicine and Environmental Medicine, Goethe University Frankfurt, Frankfurt, 60590, Germany. s.mache@uke.de.
# 2025-04-12 22:40:48,169 - DEBUG - send_request_headers.started request=<Request [b'POST']>
# 2025-04-12 22:40:48,178 - DEBUG - send_request_headers.complete
# 2025-04-12 22:40:48,178 - DEBUG - send_request_body.started request=<Request [b'POST']>
# 2025-04-12 22:40:48,180 - DEBUG - send_request_body.complete
# 2025-04-12 22:40:48,181 - DEBUG - receive_response_headers.started request=<Request [b'POST']>
# 2025-04-12 22:40:49,516 - DEBUG - receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Content-Type', b'application/json; charset=utf-8'), (b'Date', b'Sat, 12 Apr 2025 17:10:49 GMT'), (b'Content-Length', b'296')])
# 2025-04-12 22:40:49,518 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-04-12 22:40:49,518 - DEBUG - receive_response_body.started request=<Request [b'POST']>
# 2025-04-12 22:40:49,519 - DEBUG - receive_response_body.complete
# 2025-04-12 22:40:49,519 - DEBUG - response_closed.started
# 2025-04-12 22:40:49,520 - DEBUG - response_closed.complete
# 2025-04-12 22:40:49,520 - INFO - Affiliation 'Institute of Occupational Medicine, Social Medicine and Environmental Medicine, Goethe University Frankfurt, Frankfurt, 60590, Germany. s.mache@uke.de.' is academic.
# 2025-04-12 22:40:49,522 - DEBUG - No pharma/biotech affiliations found.
# 2025-04-12 22:40:49,522 - DEBUG - Company Affiliations: ['N/A'] extracted.
# 2025-04-12 22:40:49,523 - DEBUG - Extracting corresponding email from the XML data.
# 2025-04-12 22:40:49,525 - DEBUG - Checking affiliation: Institute for Occupational and Maritime Medicine (ZfAM), University Medical Center Hamburg-Eppendorf (UKE), Hamburg, 20459, Germany.
# 2025-04-12 22:40:49,527 - DEBUG - Checking affiliation: Institute for Occupational and Maritime Medicine (ZfAM), University Medical Center Hamburg-Eppendorf (UKE), Hamburg, 20459, Germany.
# 2025-04-12 22:40:49,527 - DEBUG - send_request_headers.started request=<Request [b'POST']>
# 2025-04-12 22:40:49,529 - DEBUG - send_request_headers.complete
# 2025-04-12 22:40:49,530 - DEBUG - send_request_body.started request=<Request [b'POST']>
# 2025-04-12 22:40:49,533 - DEBUG - send_request_body.complete
# 2025-04-12 22:40:49,534 - DEBUG - receive_response_headers.started request=<Request [b'POST']>
# 2025-04-12 22:40:50,867 - DEBUG - receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Content-Type', b'application/json; charset=utf-8'), (b'Date', b'Sat, 12 Apr 2025 17:10:50 GMT'), (b'Content-Length', b'296')])
# 2025-04-12 22:40:50,867 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-04-12 22:40:50,867 - DEBUG - receive_response_body.started request=<Request [b'POST']>
# 2025-04-12 22:40:50,868 - DEBUG - receive_response_body.complete
# 2025-04-12 22:40:50,869 - DEBUG - response_closed.started
# 2025-04-12 22:40:50,870 - DEBUG - response_closed.complete
# 2025-04-12 22:40:50,870 - INFO - Affiliation 'Institute for Occupational and Maritime Medicine (ZfAM), University Medical Center Hamburg-Eppendorf (UKE), Hamburg, 20459, Germany.' is academic.
# 2025-04-12 22:40:50,870 - DEBUG - Checking affiliation: Institute of Occupational Medicine, Social Medicine and Environmental Medicine, Goethe University Frankfurt, Frankfurt, 60590, Germany.
# 2025-04-12 22:40:50,870 - DEBUG - Checking affiliation: Institute of Occupational Medicine, Social Medicine and Environmental Medicine, Goethe University Frankfurt, Frankfurt, 60590, Germany.
# 2025-04-12 22:40:50,870 - DEBUG - send_request_headers.started request=<Request [b'POST']>
# 2025-04-12 22:40:50,870 - DEBUG - send_request_headers.complete
# 2025-04-12 22:40:50,877 - DEBUG - send_request_body.started request=<Request [b'POST']>
# 2025-04-12 22:40:50,880 - DEBUG - send_request_body.complete
# 2025-04-12 22:40:50,881 - DEBUG - receive_response_headers.started request=<Request [b'POST']>
# 2025-04-12 22:40:52,268 - DEBUG - receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Content-Type', b'application/json; charset=utf-8'), (b'Date', b'Sat, 12 Apr 2025 17:10:52 GMT'), (b'Content-Length', b'296')])
# 2025-04-12 22:40:52,268 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-04-12 22:40:52,268 - DEBUG - receive_response_body.started request=<Request [b'POST']>
# 2025-04-12 22:40:52,268 - DEBUG - receive_response_body.complete
# 2025-04-12 22:40:52,268 - DEBUG - response_closed.started
# 2025-04-12 22:40:52,268 - DEBUG - response_closed.complete
# 2025-04-12 22:40:52,268 - INFO - Affiliation 'Institute of Occupational Medicine, Social Medicine and Environmental Medicine, Goethe University Frankfurt, Frankfurt, 60590, Germany.' is academic.
# 2025-04-12 22:40:52,274 - DEBUG - Checking affiliation: Institute of Occupational Medicine, Social Medicine and Environmental Medicine, Goethe University Frankfurt, Frankfurt, 60590, Germany.
# 2025-04-12 22:40:52,274 - DEBUG - Checking affiliation: Institute of Occupational Medicine, Social Medicine and Environmental Medicine, Goethe University Frankfurt, Frankfurt, 60590, Germany.
# 2025-04-12 22:40:52,274 - DEBUG - send_request_headers.started request=<Request [b'POST']>
# 2025-04-12 22:40:52,278 - DEBUG - send_request_headers.complete
# 2025-04-12 22:40:52,278 - DEBUG - send_request_body.started request=<Request [b'POST']>
# 2025-04-12 22:40:52,279 - DEBUG - send_request_body.complete
# 2025-04-12 22:40:52,280 - DEBUG - receive_response_headers.started request=<Request [b'POST']>
# 2025-04-12 22:40:53,012 - DEBUG - receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Content-Type', b'application/json; charset=utf-8'), (b'Date', b'Sat, 12 Apr 2025 17:10:53 GMT'), (b'Content-Length', b'295')])
# 2025-04-12 22:40:53,013 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-04-12 22:40:53,013 - DEBUG - receive_response_body.started request=<Request [b'POST']>
# 2025-04-12 22:40:53,014 - DEBUG - receive_response_body.complete
# 2025-04-12 22:40:53,015 - DEBUG - response_closed.started
# 2025-04-12 22:40:53,017 - DEBUG - response_closed.complete
# 2025-04-12 22:40:53,018 - INFO - Affiliation 'Institute of Occupational Medicine, Social Medicine and Environmental Medicine, Goethe University Frankfurt, Frankfurt, 60590, Germany.' is academic.
# 2025-04-12 22:40:53,019 - DEBUG - Checking affiliation: Institute for Occupational and Maritime Medicine (ZfAM), University Medical Center Hamburg-Eppendorf (UKE), Hamburg, 20459, Germany. s.mache@uke.de.
# 2025-04-12 22:40:53,020 - DEBUG - Checking affiliation: Institute for Occupational and Maritime Medicine (ZfAM), University Medical Center Hamburg-Eppendorf (UKE), Hamburg, 20459, Germany. s.mache@uke.de.
# 2025-04-12 22:40:53,022 - DEBUG - send_request_headers.started request=<Request [b'POST']>
# 2025-04-12 22:40:53,024 - DEBUG - send_request_headers.complete
# 2025-04-12 22:40:53,025 - DEBUG - send_request_body.started request=<Request [b'POST']>
# 2025-04-12 22:40:53,026 - DEBUG - send_request_body.complete
# ...
# 2025-04-12 22:43:08,839 - DEBUG - send_request_headers.started request=<Request [b'POST']>
# 2025-04-12 22:43:08,841 - DEBUG - send_request_headers.complete
# 2025-04-12 22:43:08,842 - DEBUG - send_request_body.started request=<Request [b'POST']>
# 2025-04-12 22:43:08,843 - DEBUG - send_request_body.complete
# 2025-04-12 22:43:08,843 - DEBUG - receive_response_headers.started request=<Request [b'POST']>
# 2025-04-12 22:43:10,290 - DEBUG - receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Content-Type', b'application/json; charset=utf-8'), (b'Date', b'Sat, 12 Apr 2025 17:13:10 GMT'), (b'Content-Length', b'296')])
# 2025-04-12 22:43:10,291 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-04-12 22:43:10,291 - DEBUG - receive_response_body.started request=<Request [b'POST']>
# 2025-04-12 22:43:10,292 - DEBUG - receive_response_body.complete
# 2025-04-12 22:43:10,293 - DEBUG - response_closed.started
# 2025-04-12 22:43:10,294 - DEBUG - response_closed.complete
# 2025-04-12 22:43:10,295 - INFO - Affiliation 'Department of Child and Adolescent Psychiatry, Democritus University of Thrace, Alexandroupolis, GRC.' is academic.
# 2025-04-12 22:43:10,296 - DEBUG - Processing author: Pantelis Perdikaris
# 2025-04-12 22:43:10,297 - DEBUG - Checking affiliation: Department of Nursing, School of Health Sciences, University of Peloponnese, Tripolis, GRC.
# 2025-04-12 22:43:10,298 - DEBUG - Checking affiliation: Department of Nursing, School of Health Sciences, University of Peloponnese, Tripolis, GRC.
# 2025-04-12 22:43:10,300 - DEBUG - send_request_headers.started request=<Request [b'POST']>
# 2025-04-12 22:43:10,301 - DEBUG - send_request_headers.complete
# 2025-04-12 22:43:10,302 - DEBUG - send_request_body.started request=<Request [b'POST']>
# 2025-04-12 22:43:10,302 - DEBUG - send_request_body.complete
# 2025-04-12 22:43:10,305 - DEBUG - receive_response_headers.started request=<Request [b'POST']>
# 2025-04-12 22:43:11,628 - DEBUG - receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Content-Type', b'application/json; charset=utf-8'), (b'Date', b'Sat, 12 Apr 2025 17:13:11 GMT'), (b'Content-Length', b'295')])
# 2025-04-12 22:43:11,629 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-04-12 22:43:11,629 - DEBUG - receive_response_body.started request=<Request [b'POST']>
# 2025-04-12 22:43:11,629 - DEBUG - receive_response_body.complete
# 2025-04-12 22:43:11,629 - DEBUG - response_closed.started
# 2025-04-12 22:43:11,629 - DEBUG - response_closed.complete
# 2025-04-12 22:43:11,629 - INFO - Affiliation 'Department of Nursing, School of Health Sciences, University of Peloponnese, Tripolis, GRC.' is academic.
# 2025-04-12 22:43:11,629 - DEBUG - Processing author: Maria Amanatidou
# 2025-04-12 22:43:11,629 - DEBUG - Checking affiliation: Department of Nursing, University General Hospital of Alexandroupolis, Alexandroupolis, GRC.
# 2025-04-12 22:43:11,638 - DEBUG - Checking affiliation: Department of Nursing, University General Hospital of Alexandroupolis, Alexandroupolis, GRC.
# 2025-04-12 22:43:11,662 - DEBUG - send_request_headers.started request=<Request [b'POST']>
# 2025-04-12 22:43:11,664 - DEBUG - send_request_headers.complete
# 2025-04-12 22:43:11,664 - DEBUG - send_request_body.started request=<Request [b'POST']>
# 2025-04-12 22:43:11,667 - DEBUG - send_request_body.complete
# 2025-04-12 22:43:11,667 - DEBUG - receive_response_headers.started request=<Request [b'POST']>
# 2025-04-12 22:43:13,106 - DEBUG - receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Content-Type', b'application/json; charset=utf-8'), (b'Date', b'Sat, 12 Apr 2025 17:13:13 GMT'), (b'Content-Length', b'293')])
# 2025-04-12 22:43:13,106 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-04-12 22:43:13,107 - DEBUG - receive_response_body.started request=<Request [b'POST']>
# 2025-04-12 22:43:13,108 - DEBUG - receive_response_body.complete
# 2025-04-12 22:43:13,109 - DEBUG - response_closed.started
# 2025-04-12 22:43:13,111 - DEBUG - response_closed.complete
# 2025-04-12 22:43:13,111 - INFO - Affiliation 'Department of Nursing, University General Hospital of Alexandroupolis, Alexandroupolis, GRC.' is academic.
# 2025-04-12 22:43:13,112 - DEBUG - Processing author: Maria Lavdaniti
# 2025-04-12 22:43:13,112 - DEBUG - Checking affiliation: Department of Nursing, International Hellenic University, Thessaloniki, GRC.
# 2025-04-12 22:43:13,113 - DEBUG - Checking affiliation: Department of Nursing, International Hellenic University, Thessaloniki, GRC.
# 2025-04-12 22:43:13,114 - DEBUG - send_request_headers.started request=<Request [b'POST']>
# 2025-04-12 22:43:13,117 - DEBUG - send_request_headers.complete
# 2025-04-12 22:43:13,118 - DEBUG - send_request_body.started request=<Request [b'POST']>
# 2025-04-12 22:43:13,118 - DEBUG - send_request_body.complete
# 2025-04-12 22:43:13,119 - DEBUG - receive_response_headers.started request=<Request [b'POST']>
# 2025-04-12 22:43:14,502 - DEBUG - receive_response_headers.failed exception=KeyboardInterrupt()
# 2025-04-12 22:43:14,504 - DEBUG - response_closed.started
# 2025-04-12 22:43:14,507 - DEBUG - response_closed.complete
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[16], line 38
#      35         print(papers)
#      37 # Run the main function
# ---> 38 main()
#
# Cell In[16], line 29, in main()
#      26 setup_logging(debug=args.debug)
#      28 # Fetch the papers based on the query
# ---> 29 papers = fetch_all_papers(args.query, max_results=10)
#      31 # Save the results to a file or print them to the console
#      32 if args.file:
#
# Cell In[12], line 19, in fetch_all_papers(query, max_results)
#      17 for pubmed_id in paper_ids:
#      18     logging.debug(f"Fetching details for PubMed ID: {pubmed_id}")
# ---> 19     paper_details = fetch_paper_details(pubmed_id)
#      21     if paper_details:
#      22         all_paper_details.append(paper_details)
#
# Cell In[11], line 25, in fetch_paper_details(pubmed_id)
#      22 paper_details['PublicationDate'] = get_publication_date(root)
#      23 logging.debug(f"Publication Date: {paper_details['PublicationDate']} extracted.")
# ---> 25 paper_details['Authors'] = get_authors(root, "llama3:8b")
#      26 logging.debug(f"Authors: {paper_details['Authors']} extracted.")
#      28 paper_details['CompanyAffiliations'] = get_pharma_biotech_affiliations(root, pharma_biotech_keywords, "llama3:8b")
#
# Cell In[10], line 18, in get_authors(root, model)
#      16 for aff in affiliation_info:
#      17     logging.debug(f"Checking affiliation: {aff.text if aff is not None else 'N/A'}")
# ---> 18     if aff is not None and not is_academic_using_ollama(aff.text, model):
#      19         if last_name is not None and fore_name is not None:
#      20             author_name = f"{fore_name.text} {last_name.text}"
#
# Cell In[5], line 30, in is_academic_using_ollama(affiliation, model)
#      26 prompt = f"Is the following affiliation academic? {affiliation}. If academic, answer 'Yes'. Otherwise, answer 'No'."
#      28 try:
#      29     # Chat with Ollama to classify if affiliation is academic
# ---> 30     response = ollama.chat(model=model, messages=[{'role': 'user', 'content': prompt}])
#      32     # Get the response content and process it
#      33     result = response['message']['content'].strip().lower()
#
# File c:\Users\khand\AppData\Local\Programs\Python\Python312\Lib\site-packages\ollama\_client.py:333, in Client.chat(self, model, messages, tools, stream, format, options, keep_alive)
#     289 def chat(
#     290   self,
#     291   model: str = '',
#    (...)
#     298   keep_alive: Optional[Union[float, str]] = None,
#     299 ) -> Union[ChatResponse, Iterator[ChatResponse]]:
#     300   """
#     301   Create a chat response using the requested model.
#     302
#    (...)
#     331   Returns `ChatResponse` if `stream` is `False`, otherwise returns a `ChatResponse` generator.
#     332   """
# --> 333   return self._request(
#     334     ChatResponse,
#     335     'POST',
#     336     '/api/chat',
#     337     json=ChatRequest(
#     338       model=model,
#     339       messages=[message for message in _copy_messages(messages)],
#     340       tools=[tool for tool in _copy_tools(tools)],
#     341       stream=stream,
#     342       format=format,
#     343       options=options,
#     344       keep_alive=keep_alive,
#     345     ).model_dump(exclude_none=True),
#     346     stream=stream,
#     347   )
#
# File c:\Users\khand\AppData\Local\Programs\Python\Python312\Lib\site-packages\ollama\_client.py:178, in Client._request(self, cls, stream, *args, **kwargs)
#     174         yield cls(**part)
#     176   return inner()
# --> 178 return cls(**self._request_raw(*args, **kwargs).json())
#
# File c:\Users\khand\AppData\Local\Programs\Python\Python312\Lib\site-packages\ollama\_client.py:118, in Client._request_raw(self, *args, **kwargs)
#     116 def _request_raw(self, *args, **kwargs):
#     117   try:
# --> 118     r = self._client.request(*args, **kwargs)
#     119     r.raise_for_status()
#     120     return r
#
# File c:\Users\khand\AppData\Local\Programs\Python\Python312\Lib\site-packages\httpx\_client.py:837, in Client.request(self, method, url, content, data, files, json, params, headers, cookies, auth, follow_redirects, timeout, extensions)
#     822     warnings.warn(message, DeprecationWarning)
#     824 request = self.build_request(
#     825     method=method,
#     826     url=url,
#    (...)
#     835     extensions=extensions,
#     836 )
# --> 837 return self.send(request, auth=auth, follow_redirects=follow_redirects)
#
# File c:\Users\khand\AppData\Local\Programs\Python\Python312\Lib\site-packages\httpx\_client.py:926, in Client.send(self, request, stream, auth, follow_redirects)
#     922 self._set_timeout(request)
#     924 auth = self._build_request_auth(request, auth)
# --> 926 response = self._send_handling_auth(
#     927     request,
#     928     auth=auth,
#     929     follow_redirects=follow_redirects,
#     930     history=[],
#     931 )
#     932 try:
#     933     if not stream:
#
# File c:\Users\khand\AppData\Local\Programs\Python\Python312\Lib\site-packages\httpx\_client.py:954, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     951 request = next(auth_flow)
#     953 while True:
# --> 954     response = self._send_handling_redirects(
#     955         request,
#     956         follow_redirects=follow_redirects,
#     957         history=history,
#     958     )
#     959     try:
#     960         try:
#
# File c:\Users\khand\AppData\Local\Programs\Python\Python312\Lib\site-packages\httpx\_client.py:991, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     988 for hook in self._event_hooks["request"]:
#     989     hook(request)
# --> 991 response = self._send_single_request(request)
#     992 try:
#     993     for hook in self._event_hooks["response"]:
#
# File c:\Users\khand\AppData\Local\Programs\Python\Python312\Lib\site-packages\httpx\_client.py:1027, in Client._send_single_request(self, request)
#    1022     raise RuntimeError(
#    1023         "Attempted to send an async request with a sync Client instance."
#    1024     )
#    1026 with request_context(request=request):
# -> 1027     response = transport.handle_request(request)
#    1029 assert isinstance(response.stream, SyncByteStream)
#    1031 response.request = request
#
# File c:\Users\khand\AppData\Local\Programs\Python\Python312\Lib\site-packages\httpx\_transports\default.py:236, in HTTPTransport.handle_request(self, request)
#     223 req = httpcore.Request(
#     224     method=request.method,
#     225     url=httpcore.URL(
#    (...)
#     233     extensions=request.extensions,
#     234 )
#     235 with map_httpcore_exceptions():
# --> 236     resp = self._pool.handle_request(req)
#     238 assert isinstance(resp.stream, typing.Iterable)
#     240 return Response(
#     241     status_code=resp.status,
#     242     headers=resp.headers,
#     243     stream=ResponseStream(resp.stream),
#     244     extensions=resp.extensions,
#     245 )
#
# File c:\Users\khand\AppData\Local\Programs\Python\Python312\Lib\site-packages\httpcore\_sync\connection_pool.py:216, in ConnectionPool.handle_request(self, request)
#     213         closing = self._assign_requests_to_connections()
#     215     self._close_connections(closing)
# --> 216     raise exc from None
#     218 # Return the response. Note that in this case we still have to manage
#     219 # the point at which the response is closed.
#     220 assert isinstance(response.stream, Iterable)
#
# File c:\Users\khand\AppData\Local\Programs\Python\Python312\Lib\site-packages\httpcore\_sync\connection_pool.py:196, in ConnectionPool.handle_request(self, request)
#     192 connection = pool_request.wait_for_connection(timeout=timeout)
#     194 try:
#     195     # Send the request on the assigned connection.
# --> 196     response = connection.handle_request(
#     197         pool_request.request
#     198     )
#     199 except ConnectionNotAvailable:
#     200     # In some cases a connection may initially be available to
#     201     # handle a request, but then become unavailable.
#     202     #
#     203     # In this case we clear the connection and try again.
#     204     pool_request.clear_connection()
#
# File c:\Users\khand\AppData\Local\Programs\Python\Python312\Lib\site-packages\httpcore\_sync\connection.py:101, in HTTPConnection.handle_request(self, request)
#      98     self._connect_failed = True
#      99     raise exc
# --> 101 return self._connection.handle_request(request)
#
# File c:\Users\khand\AppData\Local\Programs\Python\Python312\Lib\site-packages\httpcore\_sync\http11.py:143, in HTTP11Connection.handle_request(self, request)
#     141     with Trace("response_closed", logger, request) as trace:
#     142         self._response_closed()
# --> 143 raise exc
#
# File c:\Users\khand\AppData\Local\Programs\Python\Python312\Lib\site-packages\httpcore\_sync\http11.py:113, in HTTP11Connection.handle_request(self, request)
#     102     pass
#     104 with Trace(
#     105     "receive_response_headers", logger, request, kwargs
#     106 ) as trace:
#     107     (
#     108         http_version,
#     109         status,
#     110         reason_phrase,
#     111         headers,
#     112         trailing_data,
# --> 113     ) = self._receive_response_headers(**kwargs)
#     114     trace.return_value = (
#     115         http_version,
#     116         status,
#     117         reason_phrase,
#     118         headers,
#     119     )
#     121 network_stream = self._network_stream
#
# File c:\Users\khand\AppData\Local\Programs\Python\Python312\Lib\site-packages\httpcore\_sync\http11.py:186, in HTTP11Connection._receive_response_headers(self, request)
#     183 timeout = timeouts.get("read", None)
#     185 while True:
# --> 186     event = self._receive_event(timeout=timeout)
#     187     if isinstance(event, h11.Response):
#     188         break
#
# File c:\Users\khand\AppData\Local\Programs\Python\Python312\Lib\site-packages\httpcore\_sync\http11.py:224, in HTTP11Connection._receive_event(self, timeout)
#     221     event = self._h11_state.next_event()
#     223 if event is h11.NEED_DATA:
# --> 224     data = self._network_stream.read(
#     225         self.READ_NUM_BYTES, timeout=timeout
#     226     )
#     228     # If we feed this case through h11 we'll raise an exception like:
#     229     #
#     230     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)
#     234     # perspective. Instead we handle this case distinctly and treat
#     235     # it as a ConnectError.
#     236     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File c:\Users\khand\AppData\Local\Programs\Python\Python312\Lib\site-packages\httpcore\_backends\sync.py:126, in SyncStream.read(self, max_bytes, timeout)
#     124 with map_exceptions(exc_map):
#     125     self._sock.settimeout(timeout)
# --> 126     return self._sock.recv(max_bytes)
#
# KeyboardInterrupt:

# %%
# import openai
# from dotenv import load_dotenv
# import os

# # Load the API key from the .env file
# load_dotenv()

# # Set the OpenAI API key
# openai.api_key = os.getenv("OPENAI_API_KEY")

# # Check if the API key is loaded correctly
# if openai.api_key:
#     print("API Key loaded successfully!")
# else:
#     print("Error: OpenAI API Key not found.")

# %%
# # Define the function for classifying affiliations
# def classify_affiliation_with_llm(affiliation: str) -> str:
#     prompt = f"""
# Classify the following affiliation into one of these categories: Academic, Pharma/Biotech, or Other.
# Affiliation: "{affiliation}"
# Only return one of: Academic, Pharma/Biotech, Other.
# """
#     client = openai.OpenAI()
#     completion = client.completions.create(
#         model="curie",
#         prompt=prompt,
#         temperature=0,
#         n=1
#     )
    
#     # Accessing the response using the new model's methods
#     classification = completion['choices'][0]['message']['content'].strip()
    
#     return classification

# %%
import ollama

model = "llama3:8b"
# response = ollama.chat(model=model, messages=[{'role': 'user', 'content': 'What is Ollama?'}])
# print(response['message']['content'])

# %%
# # Test with a few sample affiliations
# sample_affiliations = [
#     "Harvard University, Department of Biology",
#     "Pfizer Pharmaceuticals, Inc.",
#     "Acme Corp. - Research and Development",
#     "University of California, Berkeley",
#     "Johnson & Johnson"
# ]

# # Run the classification function on each sample
# for affiliation in sample_affiliations:
#     classification = classify_affiliation_with_llm(affiliation)
#     print(f"Affiliation: {affiliation}\nClassification: {classification}\n")

# %%
def is_academic(affiliation: str, model_name: str = "llama3:8b") -> bool:
    """
    Check if an affiliation is academic using an LLM.

    Args:
        affiliation (str): The affiliation string to check.
        model_name (str): The model to use for classification.

    Returns:
        bool: True if the affiliation is considered academic, False otherwise.
    """
    prompt = f"""
    Is the following affiliation academic or not? Reply with only 'Yes' or 'No'.

    Affiliation: "{affiliation}"
    """

    response = ollama.chat(model=model_name, messages=[{"role": "user", "content": prompt}])
    answer = response['message']['content'].strip().lower()

    return answer.startswith("yes")

# %%
def is_pharma_biotech(affiliation: str, model_name: str = "llama3:8b") -> bool:
    """
    Check if an affiliation is related to the pharmaceutical or biotech industry using an LLM.

    Args:
        affiliation (str): The affiliation string to check.
        model_name (str): The Ollama model to use. Defaults to "llama3:8b".

    Returns:
        bool: True if the affiliation is considered pharmaceutical or biotech, False otherwise.
    """
    prompt = (
        f"Is the following affiliation related to pharmaceutical or biotech industry? "
        f"Reply with only 'Yes' or 'No'.\n\nAffiliation: \"{affiliation}\""
    )

    response = ollama.chat(
        model=model_name,
        messages=[{"role": "user", "content": prompt}]
    )

    answer = response["message"]["content"].strip().lower()
    return answer.startswith("yes")

# %%
def test_is_pharma_biotech():
    # Test cases for pharma/biotech and non-pharma/biotech affiliations
    test_cases = [
        ("Pfizer Inc, Research and Development", True),  # Pharma/biotech affiliation
        ("Johnson & Johnson, Pharmaceuticals", True),  # Pharma/biotech affiliation
        ("Harvard University, Department of Computer Science", False),  # Non-pharma
        ("Biotech Labs, Inc.", True),  # Pharma/biotech affiliation
        ("Massachusetts Institute of Technology (MIT)", False),  # Non-pharma
        ("AstraZeneca Pharmaceuticals", True),  # Pharma/biotech affiliation
    ]

    for affiliation, expected_result in test_cases:
        result = is_pharma_biotech(affiliation)
        assert result == expected_result, f"Test failed for: {affiliation}. Expected {expected_result}, got {result}"

    print("All tests passed!")

if __name__ == "__main__":
    test_is_pharma_biotech()
# Out:
# 2025-04-12 22:49:10,570 - DEBUG - close.started
# 2025-04-12 22:49:10,579 - DEBUG - close.complete
# 2025-04-12 22:49:10,582 - DEBUG - connect_tcp.started host='127.0.0.1' port=11434 local_address=None timeout=None socket_options=None
# 2025-04-12 22:49:10,592 - DEBUG - connect_tcp.complete return_value=<httpcore._backends.sync.SyncStream object at 0x0000018E7F1642C0>
# 2025-04-12 22:49:10,599 - DEBUG - send_request_headers.started request=<Request [b'POST']>
# 2025-04-12 22:49:10,614 - DEBUG - send_request_headers.complete
# 2025-04-12 22:49:10,616 - DEBUG - send_request_body.started request=<Request [b'POST']>
# 2025-04-12 22:49:10,619 - DEBUG - send_request_body.complete
# 2025-04-12 22:49:10,621 - DEBUG - receive_response_headers.started request=<Request [b'POST']>
# 2025-04-12 22:49:12,838 - DEBUG - receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Content-Type', b'application/json; charset=utf-8'), (b'Date', b'Sat, 12 Apr 2025 17:19:12 GMT'), (b'Content-Length', b'297')])
# 2025-04-12 22:49:12,851 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-04-12 22:49:12,853 - DEBUG - receive_response_body.started request=<Request [b'POST']>
# 2025-04-12 22:49:12,853 - DEBUG - receive_response_body.complete
# 2025-04-12 22:49:12,860 - DEBUG - response_closed.started
# 2025-04-12 22:49:12,862 - DEBUG - response_closed.complete
# 2025-04-12 22:49:12,866 - DEBUG - send_request_headers.started request=<Request [b'POST']>
# 2025-04-12 22:49:12,870 - DEBUG - send_request_headers.complete
# 2025-04-12 22:49:12,871 - DEBUG - send_request_body.started request=<Request [b'POST']>
# 2025-04-12 22:49:12,874 - DEBUG - send_request_body.complete
# 2025-04-12 22:49:12,875 - DEBUG - receive_response_headers.started request=<Request [b'POST']>
# 2025-04-12 22:49:13,902 - DEBUG - receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Content-Type', b'application/json; charset=utf-8'), (b'Date', b'Sat, 12 Apr 2025 17:19:13 GMT'), (b'Content-Length', b'293')])
# 2025-04-12 22:49:13,903 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-04-12 22:49:13,904 - DEBUG - receive_response_body.started request=<Request [b'POST']>
# 2025-04-12 22:49:13,904 - DEBUG - receive_response_body.complete
# 2025-04-12 22:49:13,905 - DEBUG - response_closed.started
# 2025-04-12 22:49:13,905 - DEBUG - response_closed.complete
# 2025-04-12 22:49:13,909 - DEBUG - send_request_headers.started request=<Request [b'POST']>
# 2025-04-12 22:49:13,911 - DEBUG - send_request_headers.complete
# 2025-04-12 22:49:13,912 - DEBUG - send_request_body.started request=<Request [b'POST']>
# 2025-04-12 22:49:13,914 - DEBUG - send_request_body.complete
# 2025-04-12 22:49:13,915 - DEBUG - receive_response_headers.started request=<Request [b'POST']>
# 2025-04-12 22:49:14,950 - DEBUG - receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Content-Type', b'application/json; charset=utf-8'), (b'Date', b'Sat, 12 Apr 2025 17:19:14 GMT'), (b'Content-Length', b'294')])
# 2025-04-12 22:49:15,028 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-04-12 22:49:15,029 - DEBUG - receive_response_body.started request=<Request [b'POST']>
# 2025-04-12 22:49:15,029 - DEBUG - receive_response_body.complete
# 2025-04-12 22:49:15,039 - DEBUG - response_closed.started
# 2025-04-12 22:49:15,039 - DEBUG - response_closed.complete
# 2025-04-12 22:49:15,046 - DEBUG - send_request_headers.started request=<Request [b'POST']>
# 2025-04-12 22:49:15,060 - DEBUG - send_request_headers.complete
# 2025-04-12 22:49:15,061 - DEBUG - send_request_body.started request=<Request [b'POST']>
# 2025-04-12 22:49:15,061 - DEBUG - send_request_body.complete
# 2025-04-12 22:49:15,077 - DEBUG - receive_response_headers.started request=<Request [b'POST']>
# 2025-04-12 22:49:16,282 - DEBUG - receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Content-Type', b'application/json; charset=utf-8'), (b'Date', b'Sat, 12 Apr 2025 17:19:16 GMT'), (b'Content-Length', b'296')])
# 2025-04-12 22:49:16,283 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-04-12 22:49:16,283 - DEBUG - receive_response_body.started request=<Request [b'POST']>
# 2025-04-12 22:49:16,283 - DEBUG - receive_response_body.complete
# 2025-04-12 22:49:16,283 - DEBUG - response_closed.started
# 2025-04-12 22:49:16,283 - DEBUG - response_closed.complete
# 2025-04-12 22:49:16,289 - DEBUG - send_request_headers.started request=<Request [b'POST']>
# 2025-04-12 22:49:16,292 - DEBUG - send_request_headers.complete
# 2025-04-12 22:49:16,292 - DEBUG - send_request_body.started request=<Request [b'POST']>
# 2025-04-12 22:49:16,292 - DEBUG - send_request_body.complete
# 2025-04-12 22:49:16,294 - DEBUG - receive_response_headers.started request=<Request [b'POST']>
# 2025-04-12 22:49:17,392 - DEBUG - receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Content-Type', b'application/json; charset=utf-8'), (b'Date', b'Sat, 12 Apr 2025 17:19:17 GMT'), (b'Content-Length', b'294')])
# 2025-04-12 22:49:17,395 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-04-12 22:49:17,397 - DEBUG - receive_response_body.started request=<Request [b'POST']>
# 2025-04-12 22:49:17,398 - DEBUG - receive_response_body.complete
# 2025-04-12 22:49:17,402 - DEBUG - response_closed.started
# 2025-04-12 22:49:17,402 - DEBUG - response_closed.complete
# 2025-04-12 22:49:17,409 - DEBUG - send_request_headers.started request=<Request [b'POST']>
# 2025-04-12 22:49:17,414 - DEBUG - send_request_headers.complete
# 2025-04-12 22:49:17,416 - DEBUG - send_request_body.started request=<Request [b'POST']>
# 2025-04-12 22:49:17,419 - DEBUG - send_request_body.complete
# 2025-04-12 22:49:17,420 - DEBUG - receive_response_headers.started request=<Request [b'POST']>
# 2025-04-12 22:49:18,705 - DEBUG - receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Content-Type', b'application/json; charset=utf-8'), (b'Date', b'Sat, 12 Apr 2025 17:19:18 GMT'), (b'Content-Length', b'295')])
# 2025-04-12 22:49:18,709 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-04-12 22:49:18,711 - DEBUG - receive_response_body.started request=<Request [b'POST']>
# 2025-04-12 22:49:18,714 - DEBUG - receive_response_body.complete
# 2025-04-12 22:49:18,720 - DEBUG - response_closed.started
# 2025-04-12 22:49:18,724 - DEBUG - response_closed.complete
# All tests passed!
